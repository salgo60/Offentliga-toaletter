# %% [markdown]
# ## Stockholms stads offentliga toaletter
# * [#1](https://github.com/salgo60/Offentliga-toaletter/issues/1)
#    * karta [Toaletter_sthlm_latest.html](https://salgo60.github.io/Offentliga-toaletter/Notebook/Toaletter_sthlm_latest.html)
#
# ----
# * 0.1 skapade
# * 0.2 la till länkar Googfle Map etc... i popup
# * 0.3 söker fram toaletter i OSM i dag

# %%
import time
from datetime import datetime 
import glob
import pandas as pd
from datetime import date

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2026-01-25 15:06:35

# %%
#used by version 0.3 
SthlmfileName =f"data/raw/Toalett_Punkt_Sthlm_20260123.gpkg"
Mapversion = "0.4"

# used by part 2
#output_path = f"data/raw/Toalett_Punkt_Sthlm_{today}.gpkg"
output_path = f"data/raw/Toalett_Punkt_Sthlm_20260124.gpkg"

# %%
import geopandas as gpd

gdf_raw = gpd.read_file(output_path)

print("Antal objekt:", len(gdf_raw))
print("Kolumner:", list(gdf_raw.columns))
gdf_raw.head(3)
# Out:
# Antal objekt: 101
# Kolumner: ['Adress', 'Anläggningsnummer', 'Antal_WC', 'Antal_urinoarer', 'Beskrivning', 'Bild', 'CHANGE_DATE', 'CID', 'CREATE_DATE', 'Driftansvar', 'El_Service', 'FEATURE_TYPE_OBJECT_ID', 'FEATURE_TYPE_VERSION_ID', 'Fabrikat', 'Färg', 'Historisk_litterering', 'Huvudman', 'Index', 'Innehåller', 'Installerad', 'Litterering', 'MAIN_ATTRIBUTE_DESCRIPTION', 'MAIN_ATTRIBUTE_VALUE', 'Modell', 'Namn', 'OBJECT_ID', 'Projektnr', 'Pumpgrop', 'Status', 'Tillgänglighetsanpassad', 'VALID_FROM', 'VALID_TO', 'VERSION_ID', 'Vattenservice', 'fid', 'FEATURE_TYPE_NAME', 'geometry']
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyogrio/raw.py:198: RuntimeWarning: GPKG: unrecognized user_version=0x00000000 (0) on 'data/raw/Toalett_Punkt_Sthlm_20260124.gpkg'
#   return ogr_read(
#                        Adress Anläggningsnummer  Antal_WC  Antal_urinoarer  \
# 0            Frödingsvägen 13               G84       NaN              NaN
# 1  Norr Mälarstrand 3 - kajen               G60       NaN              NaN
# 2               Fjällgatan 37               G85       NaN              NaN
#
#                                          Beskrivning  Bild   CHANGE_DATE  \
# 0                                  Inbyggd i byggnad  None  2.025021e+11
# 1  Tillgänglighetsanpassad WC, 2 x WC och 1 x uri...  None  2.024012e+11
# 2                   Inbyggd endast i drift sommartid  None  2.022091e+11
#
#             CID   CREATE_DATE            Driftansvar  ... Pumpgrop  \
# 0  1.659929e+15  2.019021e+11          Miljötekniska  ...      Nej
# 1  1.538073e+15  2.018023e+11               JCDecaux  ...      Nej
# 2  1.659930e+15  2.019021e+11  Fjällgatans cafestuga  ...      Nej
#
#        Status  Tillgänglighetsanpassad    VALID_FROM VALID_TO VERSION_ID  \
# 0  I funktion                       Ja  2.019021e+11     None          1
# 1  I funktion                       Ja  2.018022e+11     None          1
# 2  I funktion                       Ja  2.019021e+11     None          1
#
#   Vattenservice fid FEATURE_TYPE_NAME                        geometry
# 0          None   1           Toalett  POINT (150163.422 6579429.646)
# 1          None   2           Toalett  POINT (152988.491 6579085.031)
# 2          None   3           Toalett  POINT (154949.341 6578026.085)
#
# [3 rows x 37 columns]

# %%
from pathlib import Path
def build_history(processed_dir="data/processed"):
    records = []

    for path in sorted(glob.glob(f"{processed_dir}/stockholm_*.parquet")):
        date = Path(path).stem.split("_")[-1]
        df = pd.read_parquet(path)

        for _, r in df.iterrows():
            records.append({
                "stable_id": r.stable_id,
                "date": date,
                "lat": r.lat,
                "lon": r.lon,
                "opening_hours": r.opening_hours,
                "accessibility": r.accessibility,
                "name": r.name,
            })

    return pd.DataFrame(records)

def popup_with_history(row, df_history):
    return folium.Popup(
        f"""
        <b>Namn:</b> {row.name_old}<br>
        <b>Ändring:</b> Attribut ändrade<br><br>
        <b>Historik:</b><br>
        {summarize_history(df_history, row.stable_id)}<br><br>
        <a href="https://www.openstreetmap.org/?mlat={row.lat_new}&mlon={row.lon_new}#map=19/{row.lat_new}/{row.lon_new}" target="_blank">
            Visa i OSM
        </a>
        """,
        max_width=400
    )

# %%
df_history = build_history()
print("Historikposter:", len(df_history))
# Out:
# Historikposter: 202

# %%
def summarize_history(df_hist, stable_id):
    h = df_hist[df_hist.stable_id == stable_id].sort_values("date")

    if h.empty:
        return "Ingen historik"

    first = h.iloc[0]["date"]
    last = h.iloc[-1]["date"]
    count = len(h)

    moved = (
        h[["lat", "lon"]]
        .diff()
        .abs()
        .sum(axis=1)
        .fillna(0)
        .gt(0.00001)
        .any()
    )

    status_changes = (
        h["opening_hours"].nunique() > 1 or
        h["accessibility"].nunique() > 1
    )

    lines = [
        f"Första observation: {first}",
        f"Senaste observation: {last}",
        f"Antal versioner: {count}",
        f"Flyttad över tid: {'Ja' if moved else 'Nej'}",
        f"Status ändrad: {'Ja' if status_changes else 'Nej'}",
    ]

    return "<br>".join(lines)

# %%
import folium 
mdiff = folium.Map(
    location=[59.3293, 18.0686],
    zoom_start=11,
    tiles="OpenStreetMap"
)

# %%
def popup(d):
    return folium.Popup(
        "<br>".join(f"<b>{k}</b>: {v}" for k, v in d.items()),
        max_width=350
    )

# %%
def timeline_table(df_hist, stable_id, limit=5):
    h = df_hist[df_hist.stable_id == stable_id].sort_values("date")
    if h.empty:
        return "Ingen historik"

    rows = h.tail(limit)

    html = "<table border='1' style='border-collapse:collapse;font-size:12px;'>"
    html += "<tr><th>Datum</th><th>Öppettider</th><th>Tillg.</th></tr>"

    for _, r in rows.iterrows():
        html += (
            f"<tr>"
            f"<td>{r.date}</td>"
            f"<td>{r.opening_hours}</td>"
            f"<td>{r.accessibility}</td>"
            f"</tr>"
        )

    html += "</table>"
    if len(h) > limit:
        html += f"<i>Visar {limit} av {len(h)} versioner</i>"

    return html

# %%
from datetime import datetime

def inactive_days(df_hist, stable_id):
    h = df_hist[df_hist.stable_id == stable_id].sort_values("date")
    if len(h) < 2:
        return 0

    last_change = h[h["opening_hours"].ne(h["opening_hours"].shift()) |
                    h["accessibility"].ne(h["accessibility"].shift())]

    if last_change.empty:
        first = datetime.strptime(h.iloc[0]["date"], "%Y%m%d")
    else:
        first = datetime.strptime(last_change.iloc[-1]["date"], "%Y%m%d")

    last = datetime.strptime(h.iloc[-1]["date"], "%Y%m%d")
    return (last - first).days

# %%
def stockholm_toalett_adapter(gdf):
    df = gdf.copy()

    # säkerställ punktgeometri
    df = df[df.geometry.notnull()]
    df["lon"] = df.geometry.x
    df["lat"] = df.geometry.y

    out = pd.DataFrame({
        "name": df.get("NAMN", df.get("namn")),
        "lat": df["lat"],
        "lon": df["lon"],
        "opening_hours": df.get("OPPETTIDER", df.get("oppettider")),
        "accessibility": df.get("TILLGANG", df.get("tillganglighet")),
    })

    # rensa minimalt
    out["name"] = out["name"].astype(str).str.strip()

    # stabilt ID (≈ 1 m)
    out["stable_id"] = (
        out["lat"].round(5).astype(str)
        + "_"
        + out["lon"].round(5).astype(str)
    )

    return out.dropna(subset=["lat", "lon"])

# %%
df_new = stockholm_toalett_adapter(gdf_raw)
print("Adapter-resultat:", len(df_new))
# Out:
# Adapter-resultat: 101

# %%
df_old = None
added = pd.DataFrame()
removed = pd.DataFrame()
changed_geom = pd.DataFrame()
changed_attrs = pd.DataFrame()

if df_old is not None:
    added = df_new[~df_new["stable_id"].isin(df_old["stable_id"])]
    removed = df_old[~df_old["stable_id"].isin(df_new["stable_id"])]

    merged = df_old.merge(
        df_new,
        on="stable_id",
        suffixes=("_old", "_new")
    )

    changed_geom = merged[
        (merged["lat_old"] != merged["lat_new"]) |
        (merged["lon_old"] != merged["lon_new"])
    ]

    changed_attrs = merged[
        (merged["opening_hours_old"] != merged["opening_hours_new"]) |
        (merged["accessibility_old"] != merged["accessibility_new"])
    ]

# %%
import folium 
fg_added = folium.FeatureGroup(name="🟢 Tillkomna")
today = date.today().strftime("%Y%m%d") 



for _, r in added.iterrows():
    popup_html = f"""
        <b>Namn:</b> {r.name_old}<br>
        <b>Ändring:</b> Attribut ändrade<br><br>
        
        <b>Historik:</b><br>
        {timeline_table(df_history, r.stable_id)}<br><br>
        
        <a href="https://www.openstreetmap.org/?mlat={r.lat_new}&mlon={r.lon_new}#map=19/{r.lat_new}/{r.lon_new}" target="_blank">
        Visa i OSM
        </a>
        """
    folium.CircleMarker(
        [r.lat, r.lon],
        radius=6,
        color="green",
        fill=True,
        fill_opacity=0.8,
        popup=popup({
            "Namn": r.name,
            "Ändring": "Tillkommen"
        })
    ).add_to(fg_added)

fg_added.add_to(mdiff) 

fg_removed = folium.FeatureGroup(name="🔴 Borttagna")

for _, r in removed.iterrows():
    folium.CircleMarker(
        [r.lat, r.lon],
        radius=6,
        color="red",
        fill=True,
        fill_opacity=0.8,
        popup=popup({
            "Namn": r.name,
            "Ändring": "Borttagen"
        })
    ).add_to(fg_removed)

fg_removed.add_to(mdiff)

fg_moved = folium.FeatureGroup(name="🟠 Flyttade")

for _, r in changed_geom.iterrows():
    old = (r.lat_old, r.lon_old)
    new = (r.lat_new, r.lon_new)

    folium.PolyLine([old, new], color="orange", weight=2).add_to(fg_moved)

    folium.CircleMarker(old, radius=5, color="orange", fill=True).add_to(fg_moved)
    folium.CircleMarker(
        new, radius=7, color="orange", fill=True,
        popup=popup({
            "Namn": r.name_old,
            "Gammal position": old,
            "Ny position": new
        })
    ).add_to(fg_moved)

fg_moved.add_to(mdiff)

fg_changed = folium.FeatureGroup(name="🟡 Ändrade attribut")

for _, r in changed_attrs.iterrows():
    folium.CircleMarker(
        [r.lat_new, r.lon_new],
        radius=6,
        color="gold",
        fill=True,
        fill_opacity=0.8,
        popup=popup_with_history(r, df_history)
    ).add_to(fg_changed)


fg_changed.add_to(mdiff)

folium.LayerControl(collapsed=False).add_to(mdiff)

legend_html = f"""
<div style="
 position: fixed;
 bottom: 30px;
 left: 30px;
 z-index: 9999;
 background-color: white;
 padding: 10px;
 border: 2px solid grey;
 font-size: 14px;
">
<b>Legend – Toaletter Stockholm (diff)</b><br>
<span style="color:green;">●</span> Tillkommen<br>
<span style="color:red;">●</span> Borttagen<br>
<span style="color:orange;">●</span> Flyttad<br>
<span style="color:gold;">●</span> Attribut ändrat<br>
<hr> Analys: versionsjämförelse {today}<br /><br />
<b> Mer info</b><br>
• <a href="https://github.com/salgo60/Offentliga-toaletter/issues/8" target="_blank">GitHub Issue #8</a><br>
• <a href="https://dataportalen.stockholm.se/dataportalen/GetMetaDataById?id=LvFeature15303196&showmetadataview" target="_blank">
   Stockholms stads öppna data</a>
</div>
"""
mdiff.get_root().html.add_child(folium.Element(legend_html))

mdiff_Filename = f"Toaletter_sthlm_diff_{today}.html"
mdiff.save(mdiff_Filename)

print("Klar: ", mdiff_Filename)
# Out:
# Klar:  Toaletter_sthlm_diff_20260125.html

# %%
mdiff
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27ee46e714af40731958084f83cce12d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#  position: fixed;
#  bottom: 30px;
#  left: 30px;
#  z-index: 9999;
#  background-color: white;
#  padding: 10px;
#  border: 2px solid grey;
#  font-size: 14px;
# &quot;&gt;
# &lt;b&gt;Legend – Toaletter Stockholm (diff)&lt;/b&gt;&lt;br&gt;
# &lt;span style=&quot;color:green;&quot;&gt;●&lt;/span&gt; Tillkommen&lt;br&gt;
# &lt;span style=&quot;color:red;&quot;&gt;●&lt;/span&gt; Borttagen&lt;br&gt;
# &lt;span style=&quot;color:orange;&quot;&gt;●&lt;/span&gt; Flyttad&lt;br&gt;
# &lt;span style=&quot;color:gold;&quot;&gt;●&lt;/span&gt; Attribut ändrat&lt;br&gt;
# &lt;hr&gt; Analys: versionsjämförelse 20260125&lt;br /&gt;&lt;br /&gt;
# &lt;b&gt; Mer info&lt;/b&gt;&lt;br&gt;
# • &lt;a href=&quot;https://github.com/salgo60/Offentliga-toaletter/issues/8&quot; target=&quot;_blank&quot;&gt;GitHub Issue #8&lt;/a&gt;&lt;br&gt;
# • &lt;a href=&quot;https://dataportalen.stockholm.se/dataportalen/GetMetaDataById?id=LvFeature15303196&amp;showmetadataview&quot; target=&quot;_blank&quot;&gt;
#    Stockholms stads öppna data&lt;/a&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27ee46e714af40731958084f83cce12d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27ee46e714af40731958084f83cce12d = L.map(
#                 &quot;map_27ee46e714af40731958084f83cce12d&quot;,
#                 {
#                     center: [59.3293, 18.0686],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_610c5bf6bafdb5be4a128a24407dee64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_610c5bf6bafdb5be4a128a24407dee64.addTo(map_27ee46e714af40731958084f83cce12d);
#
#
#             var feature_group_8abb3b42782fcf566427280bbd085fb9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8abb3b42782fcf566427280bbd085fb9.addTo(map_27ee46e714af40731958084f83cce12d);
#
#
#             var feature_group_321b8fe62476a710e1520c973cf06920 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_321b8fe62476a710e1520c973cf06920.addTo(map_27ee46e714af40731958084f83cce12d);
#
#
#             var feature_group_327009cadbe87cc23ad14dcd1ff37016 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_327009cadbe87cc23ad14dcd1ff37016.addTo(map_27ee46e714af40731958084f83cce12d);
#
#
#             var feature_group_c695378b16fe3fbc4711fa8a732895ed = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c695378b16fe3fbc4711fa8a732895ed.addTo(map_27ee46e714af40731958084f83cce12d);
#
#
#             var layer_control_da960eb9e30f2632482c199c1c7d604a_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_610c5bf6bafdb5be4a128a24407dee64,
#                 },
#                 overlays :  {
#                     &quot;\ud83d\udfe2 Tillkomna&quot; : feature_group_8abb3b42782fcf566427280bbd085fb9,
#                     &quot;\ud83d\udd34 Borttagna&quot; : feature_group_321b8fe62476a710e1520c973cf06920,
#                     &quot;\ud83d\udfe0 Flyttade&quot; : feature_group_327009cadbe87cc23ad14dcd1ff37016,
#                     &quot;\ud83d\udfe1 \u00c4ndrade attribut&quot; : feature_group_c695378b16fe3fbc4711fa8a732895ed,
#                 },
#             };
#             let layer_control_da960eb9e30f2632482c199c1c7d604a = L.control.layers(
#                 layer_control_da960eb9e30f2632482c199c1c7d604a_layers.base_layers,
#                 layer_control_da960eb9e30f2632482c199c1c7d604a_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_27ee46e714af40731958084f83cce12d);
#
#
#
#             tile_layer_610c5bf6bafdb5be4a128a24407dee64.addTo(map_27ee46e714af40731958084f83cce12d);
#
#
#             feature_group_8abb3b42782fcf566427280bbd085fb9.addTo(map_27ee46e714af40731958084f83cce12d);
#
#
#             feature_group_321b8fe62476a710e1520c973cf06920.addTo(map_27ee46e714af40731958084f83cce12d);
#
#
#             feature_group_327009cadbe87cc23ad14dcd1ff37016.addTo(map_27ee46e714af40731958084f83cce12d);
#
#
#             feature_group_c695378b16fe3fbc4711fa8a732895ed.addTo(map_27ee46e714af40731958084f83cce12d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !impor

# %%
from pathlib import Path 
Path("data/processed").mkdir(parents=True, exist_ok=True)

processed_files = sorted(glob.glob("data/processed/stockholm_*.parquet"))
df_old = pd.read_parquet(processed_files[-1]) if processed_files else None

df_new.to_parquet(f"data/processed/stockholm_{today}.parquet")

added = removed = changed_geom = changed_attrs = pd.DataFrame()

if df_old is not None:
    added = df_new[~df_new.stable_id.isin(df_old.stable_id)]
    removed = df_old[~df_old.stable_id.isin(df_new.stable_id)]

    merged = df_old.merge(
        df_new,
        on="stable_id",
        suffixes=("_old", "_new")
    )

    changed_geom = merged[
        (merged.lat_old != merged.lat_new) |
        (merged.lon_old != merged.lon_new)
    ]

    changed_attrs = merged[
        (merged.opening_hours_old != merged.opening_hours_new) |
        (merged.accessibility_old != merged.accessibility_new)
    ]

print(
    "Tillkomna:", len(added),
    "Borttagna:", len(removed),
    "Flyttade:", len(changed_geom),
    "Ändrade attribut:", len(changed_attrs)
)
# Out:
# Tillkomna: 0 Borttagna: 0 Flyttade: 0 Ändrade attribut: 101

# %% [markdown]
# ## Karta Offentliga toaletter
# * visat karta med OSM offentliga toaletter och Stockholms stad

# %%
import geopandas as gpd

# Läs in geopackage-filen
gdf = gpd.read_file(SthlmfileName)

# Visa grundläggande information
print(gdf.head())
print(gdf.crs)
print(gdf.columns)
# Out:
#                            Adress Anläggningsnummer  Antal_WC  \
# 0                Frödingsvägen 13               G84       NaN
# 1      Norr Mälarstrand 3 - kajen               G60       NaN
# 2                   Fjällgatan 37               G85       NaN
# 3                   Sveavägen 39A               G67       NaN
# 4  Norra Bantorget - Vasagatan 59               G14       1.0
#
#    Antal_urinoarer                                        Beskrivning  Bild  \
# 0              NaN                                  Inbyggd i byggnad  None
# 1              NaN  Tillgänglighetsanpassad WC, 2 x WC och 1 x uri...  None
# 2              NaN                   Inbyggd endast i drift sommartid  None
# 3              NaN                            Tillgänglighetsanpassad  None
# 4              NaN                         Tillgänglighetsanpassad WC  None
#
#     CHANGE_DATE           CID   CREATE_DATE            Driftansvar  ...  \
# 0  2.025021e+11  1.659929e+15  2.019021e+11          Miljötekniska  ...
# 1  2.024012e+11  1.538073e+15  2.018023e+11               JCDecaux  ...
# 2  2.022091e+11  1.659930e+15  2.019021e+11  Fjällgatans cafestuga  ...
# 3  2.024012e+11  1.538074e+15  2.018023e+11               JCDecaux  ...
# 4  2.024012e+11  1.530323e+15  2.018011e+11               JCDecaux  ...
#
#   Pumpgrop      Status  Tillgänglighetsanpassad    VALID_FROM VALID_TO  \
# 0      Nej  I funktion                       Ja  2.019021e+11     None
# 1      Nej  I funktion                       Ja  2.018022e+11     None
# 2      Nej  I funktion                       Ja  2.019021e+11     None
# 3      Nej  I funktion                       Ja  2.018022e+11     None
# 4      Nej  I funktion                       Ja  2.018011e+11     None
#
#   VERSION_ID Vattenservice fid FEATURE_TYPE_NAME  \
# 0          1          None   1           Toalett
# 1          1          None   2           Toalett
# 2          1          None   3           Toalett
# 3          1          None   4           Toalett
# 4          1          None   5           Toalett
#
#                          geometry
# 0  POINT (150163.422 6579429.646)
# 1  POINT (152988.491 6579085.031)
# 2  POINT (154949.341 6578026.085)
# 3  POINT (153474.156 6580313.629)
# 4  POINT (153148.155 6579983.768)
#
# [5 rows x 37 columns]
# EPSG:3011
# Index(['Adress', 'Anläggningsnummer', 'Antal_WC', 'Antal_urinoarer',
#        'Beskrivning', 'Bild', 'CHANGE_DATE', 'CID', 'CREATE_DATE',
#        'Driftansvar', 'El_Service', 'FEATURE_TYPE_OBJECT_ID',
#        'FEATURE_TYPE_VERSION_ID', 'Fabrikat', 'Färg', 'Historisk_litterering',
#        'Huvudman', 'Index', 'Innehåller', 'Installerad', 'Litterering',
#        'MAIN_ATTRIBUTE_DESCRIPTION', 'MAIN_ATTRIBUTE_VALUE', 'Modell', 'Namn',
#        'OBJECT_ID', 'Projektnr', 'Pumpgrop', 'Status',
#        'Tillgänglighetsanpassad', 'VALID_FROM', 'VALID_TO', 'VERSION_ID',
#        'Vattenservice', 'fid', 'FEATURE_TYPE_NAME', 'geometry'],
#       dtype='object')
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyogrio/raw.py:198: RuntimeWarning: GPKG: unrecognized user_version=0x00000000 (0) on 'data/raw/Toalett_Punkt_Sthlm_20260123.gpkg'
#   return ogr_read(

# %%
def convert_misread_date(x):
    try:
        if pd.isna(x):
            return None
        # gör till int, ta bara siffrorna
        s = str(int(float(x)))
        # om 8 tecken → YYYYMMDD
        if len(s) == 8:
            return pd.to_datetime(s, format="%Y%m%d", errors="coerce")
        return None
    except Exception:
        return None

for col in [c for c in gdf.columns if "DATE" in c.upper()]:
    gdf[col + "_fmt"] = gdf[col].apply(convert_misread_date)

# %%
import geopandas as gpd
import pandas as pd

# Läs in
gdf = gpd.read_file(SthlmfileName)

# Beräkna centroid i meter-CRS (SWEREF99 TM) och konvertera till WGS84
gdf_proj = gdf.to_crs(epsg=3006)
gdf["geometry_centroid"] = gdf_proj.geometry.centroid.to_crs(epsg=4326)

# Lägg till lat/lon
gdf["lon"] = gdf["geometry_centroid"].x
gdf["lat"] = gdf["geometry_centroid"].y

# Lista möjliga datumkolumner
date_cols = [c for c in gdf.columns if "DATE" in c.upper() or "DATUM" in c.upper()]
print("🕒 Datumkolumner:", date_cols)

# Funktion för att försöka tolka stora siffror som tidsstämplar
def convert_date(x):
    try:
        # Om NaN
        if pd.isna(x):
            return None
        # Om redan datetime
        if isinstance(x, pd.Timestamp):
            return x
        # Om det ser ut som 1.738443e+15 (millisekunder)
        x = float(x)
        if x > 1e12:  # troligen millisekunder
            return pd.to_datetime(x, unit="ms")
        elif x > 1e9:  # sekunder
            return pd.to_datetime(x, unit="s")
        else:
            return None
    except Exception:
        return None

# Konvertera alla identifierade datumfält
for col in date_cols:
    gdf[col + "_fmt"] = gdf[col].apply(convert_date)

# Visa exempel på konverterade datum
print(gdf[[c for c in gdf.columns if "DATE" in c or "fmt" in c]].head())

gdf.drop(columns=["geometry", "geometry_centroid"]).to_csv("SthlmfileName_Toalett_fix.csv", index=False)
print("✅ Sparade 'SthlmfileName_Toalett_fix.csv' med riktiga datum och koordinater")
# Out:
# 🕒 Datumkolumner: ['CHANGE_DATE', 'CREATE_DATE']
#     CHANGE_DATE   CREATE_DATE CHANGE_DATE_fmt CREATE_DATE_fmt
# 0  2.025021e+11  2.019021e+11            None            None
# 1  2.024012e+11  2.018023e+11            None            None
# 2  2.022091e+11  2.019021e+11            None            None
# 3  2.024012e+11  2.018023e+11            None            None
# 4  2.024012e+11  2.018011e+11            None            None
# ✅ Sparade 'SthlmfileName_Toalett_fix.csv' med riktiga datum och koordinater
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyogrio/raw.py:198: RuntimeWarning: GPKG: unrecognized user_version=0x00000000 (0) on 'data/raw/Toalett_Punkt_Sthlm_20260123.gpkg'
#   return ogr_read(

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 42 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Adress                      101 non-null    object
#  1   Anläggningsnummer           101 non-null    object
#  2   Antal_WC                    4 non-null      float64
#  3   Antal_urinoarer             2 non-null      float64
#  4   Beskrivning                 75 non-null     object
#  5   Bild                        1 non-null      object
#  6   CHANGE_DATE                 101 non-null    float64
#  7   CID                         101 non-null    float64
#  8   CREATE_DATE                 101 non-null    float64
#  9   Driftansvar                 101 non-null    object
#  10  El_Service                  0 non-null      object
#  11  FEATURE_TYPE_OBJECT_ID      101 non-null    int64
#  12  FEATURE_TYPE_VERSION_ID     101 non-null    int16
#  13  Fabrikat                    97 non-null     object
#  14  Färg                        101 non-null    object
#  15  Historisk_litterering       0 non-null      object
#  16  Huvudman                    101 non-null    object
#  17  Index                       77 non-null     object
#  18  Innehåller                  0 non-null      object
#  19  Installerad                 0 non-null      object
#  20  Litterering                 101 non-null    object
#  21  MAIN_ATTRIBUTE_DESCRIPTION  101 non-null    object
#  22  MAIN_ATTRIBUTE_VALUE        101 non-null    object
#  23  Modell                      94 non-null     object
#  24  Namn                        101 non-null    object
#  25  OBJECT_ID                   101 non-null    int64
#  26  Projektnr                   0 non-null      object
#  27  Pumpgrop                    71 non-null     object
#  28  Status                      101 non-null    object
#  29  Tillgänglighetsanpassad     101 non-null    object
#  30  VALID_FROM                  101 non-null    float64
#  31  VALID_TO                    0 non-null      object
#  32  VERSION_ID                  101 non-null    int16
#  33  Vattenservice               0 non-null      object
#  34  fid                         101 non-null    int32
#  35  FEATURE_TYPE_NAME           101 non-null    object
#  36  geometry                    101 non-null    geometry
#  37  geometry_centroid           101 non-null    geometry
#  38  lon                         101 non-null    float64
#  39  lat                         101 non-null    float64
#  40  CHANGE_DATE_fmt             0 non-null      object
#  41  CREATE_DATE_fmt             0 non-null      object
# dtypes: float64(8), geometry(2), int16(2), int32(1), int64(2), object(27)
# memory usage: 31.7+ KB

# %%
gdf.describe()
# Out:
#        Antal_WC  Antal_urinoarer   CHANGE_DATE           CID   CREATE_DATE  \
# count       4.0              2.0  1.010000e+02  1.010000e+02  1.010000e+02
# mean        1.0              1.0  2.024175e+11  1.747852e+15  2.019862e+11
# std         0.0              0.0  7.942318e+07  3.398323e+14  2.930167e+08
# min         1.0              1.0  2.022090e+11  1.530321e+15  2.018011e+11
# 25%         1.0              1.0  2.024012e+11  1.530326e+15  2.018011e+11
# 50%         1.0              1.0  2.024012e+11  1.538074e+15  2.018023e+11
# 75%         1.0              1.0  2.025101e+11  1.775757e+15  2.020092e+11
# max         1.0              1.0  2.025102e+11  2.358270e+15  2.025101e+11
#
#        FEATURE_TYPE_OBJECT_ID  FEATURE_TYPE_VERSION_ID     OBJECT_ID  \
# count                   101.0                    101.0  1.010000e+02
# mean               15303196.0                      1.0  1.747852e+07
# std                       0.0                      0.0  3.398322e+06
# min                15303196.0                      1.0  1.530321e+07
# 25%                15303196.0                      1.0  1.530326e+07
# 50%                15303196.0                      1.0  1.538074e+07
# 75%                15303196.0                      1.0  1.775757e+07
# max                15303196.0                      1.0  2.358270e+07
#
#          VALID_FROM  VERSION_ID         fid         lon         lat
# count  1.010000e+02       101.0  101.000000  101.000000  101.000000
# mean   2.019861e+11         1.0   51.000000   18.028833   59.323680
# std    2.930255e+08         0.0   29.300171    0.064846    0.032642
# min    2.018011e+11         1.0    1.000000   17.843198   59.243971
# 25%    2.018011e+11         1.0   26.000000   18.002871   59.301593
# 50%    2.018022e+11         1.0   51.000000   18.052149   59.326010
# 75%    2.020092e+11         1.0   76.000000   18.075276   59.339646
# max    2.025101e+11         1.0  101.000000   18.130955   59.413180

# %%
from shapely.geometry import base

for col in gdf.columns:
    has_geom = gdf[col].apply(lambda x: isinstance(x, base.BaseGeometry)).any()
    if has_geom:
        print(f"🧱 Kolumn '{col}' innehåller geometrier")
# Out:
# 🧱 Kolumn 'geometry' innehåller geometrier
# 🧱 Kolumn 'geometry_centroid' innehåller geometrier

# %%
from urllib.parse import unquote

def build_commons_thumbnail(tags: dict, width: int = 240) -> str:
    image_url = tags.get("image")
    if not image_url:
        return ""

    if "/wiki/File:" not in image_url:
        return ""

    filename = image_url.split("/wiki/File:")[-1]
    filename = unquote(filename)  # hantera %C3%A5 etc korrekt

    thumb_url = (
        "https://commons.wikimedia.org/wiki/Special:FilePath/"
        f"{filename}?width={width}"
    )

    return f"""
    <div style="margin-top:6px;text-align:center;">
      <a href="{image_url}" target="_blank">
        <img src="{thumb_url}"
             style="max-width:100%;
                    border-radius:6px;
                    box-shadow:0 1px 4px rgba(0,0,0,0.3);"
             loading="lazy"
             alt="Wikimedia Commons image">
      </a>
      <div style="font-size:12px;color:#555;margin-top:2px;">
        Klicka för full storlek (Wikimedia Commons)
      </div>
    </div>
    """

# %%
from urllib.parse import quote

def build_toilet_popup(row, *, include_source=True):    
    lat = row["lat"]
    lon = row["lon"]

    name = "Offentlig toalett"
    address = row.get("Adress", "")
    status = row.get("Status", "")
    operator = row.get("Driftansvar", "Stockholms stad")
    accessible = row.get("Tillgänglighetsanpassad", "")
    facility_id = row.get("Anläggningsnummer", "")

    # --- Tillgänglighet ---
    wheelchair_html = {
        "Ja": "♿ <b>Tillgänglig:</b> Ja ✅<br>",
        "Nej": "♿ <b>Tillgänglig:</b> Nej ❌<br>",
    }.get(accessible, "♿ <b>Tillgänglig:</b> Okänd ❔<br>")

    # --- OSM Note ---
    note_text = (
        f"Kommunal toalett enligt Stockholms stad. "
        f"Adress: {address}. "
        f"Tillgänglig: {accessible}. "
        f"Anläggningsnummer: {facility_id}."
    )
    note_url = (
        f"https://www.openstreetmap.org/note/new"
        f"#map=18/{lat}/{lon}&text={quote(note_text)}"
    )

    mapcomplete = f"https://mapcomplete.org/toilets.html?z=17&lat={lat}&lon={lon}#about_theme"
    wheelmap = f"https://wheelmap.org/map#/?lat={lat}&lon={lon}&zoom=17"
    # --- App / editor-länkar ---
    google_maps = f"https://maps.google.com/?q={lat},{lon}"
    streetview = f"https://www.google.com/maps/@?api=1&map_action=pano&viewpoint={lat},{lon}"
    wikishootme = f"https://wikishootme.toolforge.org/#lat={lat}&lng={lon}&zoom=17"
    
    menu_html = f"""
        <div style='margin-top:8px; text-align:center;'>
          <a href='{mapcomplete}' target='_blank'
             style='background:#34a853;color:white;padding:6px 10px;
                    border-radius:6px;text-decoration:none;margin:2px;
                    display:inline-block;font-size:13px;'>
             🚻 MapComplete – Toilets
          </a>
        
          <a href='{wheelmap}' target='_blank'
             style='background:#7c3aed;color:white;padding:6px 10px;
                    border-radius:6px;text-decoration:none;margin:2px;
                    display:inline-block;font-size:13px;'>
             ♿ Wheelmap
          </a>
        
          <a href='{note_url}' target='_blank'
             style='background:#fbbc04;color:black;padding:6px 10px;
                    border-radius:6px;text-decoration:none;margin:2px;
                    display:inline-block;font-size:13px;'>
             📝 OSM Note
          </a>
        </div>
        """

    tools_html = f"""
    <details style='margin-top:6px; text-align:center;'>
      <summary style='cursor:pointer;font-weight:bold;'>🔗 Fler kartverktyg</summary>
      <a href='https://www.openstreetmap.org/edit#map=18/{lat}/{lon}' target='_blank'>✏️ iD Editor</a><br>
      <a href='https://www.mapillary.com/app/?lat={lat}&lng={lon}&z=17' target='_blank'>🟢 Mapillary</a><br>
      <a href='{google_maps}' target='_blank'>🗺️ Google Maps</a><br>
      <a href='{streetview}' target='_blank'>👁️ Google Street View</a><br>
      <a href='{wikishootme}' target='_blank'>🧭 Wikishootme</a><br>
    </details>
    """

    source_html = ""
    if include_source:
        source_html ="""<hr style="margin:6px 0;">
          <small>
            <b>Källa:</b>
            <a href="https://dataportalen.stockholm.se/dataportalen/GetMetaDataById?id=LvFeature15303196&showmetadataview"
               target="_blank">
               Stockholms stads öppna data
            </a>
          </small>"""
 
    popup_html = f"""
    <div style='font-family:Arial; font-size:13px; max-width:320px;'>
      <b>🚻 {name}</b><br>
      <b>Adress:</b> {address}<br>
      <b>Status:</b> {status}<br>
      <b>Driftansvar:</b> {operator}<br>
      <b>Anläggningsnr:</b> {facility_id}<br>
      {wheelchair_html}
      📍 <a href='https://www.openstreetmap.org/?mlat={lat}&mlon={lon}#map=18/{lat}/{lon}'
            target='_blank'>{lat:.5f}, {lon:.5f}</a><br>

      {menu_html}
      {tools_html}
      {source_html}
    </div>
    """
    return popup_html

# %%
def build_external_media_links(tags: dict) -> str:
    links = []

    # Wikimedia Commons – image (direkt fil)
    image = tags.get("image")
    if image and image.startswith("https://commons.wikimedia.org/wiki/"):
        links.append(
            f'🖼️ <a href="{image}" target="_blank">Bild (Wikimedia Commons)</a>'
        )

    # Wikimedia Commons – category eller file via wikimedia_commons
    commons = tags.get("wikimedia_commons")
    if commons:
        commons_url = f"https://commons.wikimedia.org/wiki/{commons}"
        links.append(
            f'📂 <a href="{commons_url}" target="_blank">Commons-kategori</a>'
        )

    # Mapillary
    mapillary_key = tags.get("mapillary")
    if mapillary_key and mapillary_key.isdigit():
        mapillary_url = f"https://www.mapillary.com/app/?pKey={mapillary_key}"
        links.append(
            f'📷 <a href="{mapillary_url}" target="_blank">Mapillary-bild</a>'
        )

    if not links:
        return ""

    return (
        "<div style='margin-top:6px;'>"
        "<b>🔗 Media</b><br>"
        + "<br>".join(links) +
        "</div>"
    )

# %%
def build_osm_toilet_popup(osm_el: dict, *, lat: float, lon: float) -> str:
    tags = osm_el.get("tags", {})
    osm_id = osm_el["id"]
    osm_type = osm_el["type"]

    row = {
        "lat": lat,
        "lon": lon,
        "Tillgänglighetsanpassad": tags.get("wheelchair", ""),
    }

    base_popup = build_toilet_popup(row, include_source=False)

    osm_object_url = f"https://www.openstreetmap.org/node/{osm_id}"
    tags_html = render_osm_tags(tags)
    warnings_html = get_data_quality_warnings(tags)
    mapcomplete_link = build_mapcomplete_link(lat, lon, tags)

    media_links_html = build_external_media_links(tags)
    commons_thumb_html = build_commons_thumbnail(tags)

    osm_section = f"""
    <hr style="margin:6px 0;">
    <b>🧾 OpenStreetMap</b><br>
    <a href="{osm_object_url}" target="_blank">Node {osm_id}</a><br>

    {commons_thumb_html}
    {media_links_html}
    
    <div style="margin-top:6px;text-align:center;">
      <a href="{mapcomplete_link}" target="_blank"
         style="background:#34a853;color:white;
                padding:6px 10px;border-radius:6px;
                text-decoration:none;font-size:13px;">
        🚻 Edit in MapComplete (prefilled)
      </a>
    </div>

    {warnings_html}

    <details style="margin-top:6px;">
      <summary style="cursor:pointer;font-weight:bold;">
        🏷️ OSM Tags
      </summary>
      {tags_html}
    </details>
    """

    return base_popup.replace("</div>", osm_section + "</div>")

# %%
def build_mapcomplete_link(lat, lon, tags: dict) -> str:
    """
    Build MapComplete Toilets link with prefilled tags.
    """
    base = "https://mapcomplete.org/toilets.html"

    allowed_keys = {
        "wheelchair",
        "fee",
        "access",
        "unisex",
        "changing_table",
        "toilets:disposal",
        "toilets:position",
        "drinking_water",
    }

    preset_tags = {
        k: v for k, v in tags.items()
        if k in allowed_keys
    }

    tag_fragment = "&".join(
        f"{quote(k)}={quote(v)}" for k, v in preset_tags.items()
    )

    return (
        f"{base}?z=18&lat={lat}&lon={lon}"
        f"#preset=toilets"
        + (f"&{tag_fragment}" if tag_fragment else "")
    )

# %%
def get_data_quality_warnings(tags: dict, stale_years: int = 3) -> str:
    """
    Highlight questionable OSM data such as fixme or old check_date.
    """
    warnings = []

    # fixme=* is always suspicious
    if "fixme" in tags:
        warnings.append(
            f"⚠️ <b>fixme:</b> {tags.get('fixme')}"
        )

    # check_date staleness
    cd = tags.get("check_date")
    parsed = parse_osm_date(cd) if cd else None
    if parsed:
        age = date.today().year - parsed.year
        if age >= stale_years:
            warnings.append(
                f"⏰ <b>check_date:</b> {cd} (≈ {age} years old)"
            )

    if not warnings:
        return ""

    return (
        "<div style='background:#fff3cd;"
        "border:1px solid #ffecb5;"
        "padding:6px;border-radius:6px;"
        "margin-top:6px;font-size:12px;'>"
        "<b>Datakvalitet</b><br>"
        + "<br>".join(warnings) +
        "</div>"
    )

# %%
def render_osm_tags(tags: dict) -> str:
    """
    Render OSM tags as HTML with links to OSM Wiki for each key.
    """
    if not tags:
        return "<i>No tags</i>"

    rows = []
    for k, v in sorted(tags.items()):
        wiki = f"https://wiki.openstreetmap.org/wiki/Key:{quote(k)}"
        rows.append(
            f"<tr>"
            f"<td style='padding-right:6px;'><a href='{wiki}' target='_blank'><code>{k}</code></a></td>"
            f"<td><code>{v}</code></td>"
            f"</tr>"
        )

    return (
        "<table style='border-collapse:collapse;font-size:12px;'>"
        + "".join(rows)
        + "</table>"
    )

# %%
from datetime import date, datetime
def parse_osm_date(value: str):
    """
    Parse OSM-style date (YYYY-MM-DD). Return date or None.
    """
    try:
        return datetime.strptime(value, "%Y-%m-%d").date()
    except Exception:
        return None

# %% [markdown]
# ### Open Street Map layer

# %%
import requests
import json
import os
import time
from pathlib import Path  

def get_lat_lon(el):
    if el["type"] == "node":
        return el.get("lat"), el.get("lon")
    if el["type"] in ("way", "relation"):
        center = el.get("center")
        if center:
            return center.get("lat"), center.get("lon")
    return None, None

# 🗺️ Overpass API
OVERPASS_URL = "https://overpass-api.de/api/interpreter"

# 🔍 Overpass query (fixed)
OVERPASS_QUERY = """
[out:json][timeout:60];
area(3600398021)->.searchArea;
nwr["amenity"="toilets"](area.searchArea);
out center;
"""

# 💾 Cache settings
CACHE_FILE = Path("osm_Sthlmkommun_cache.json")
#CACHE_TTL = 60  # seconds (dev default)
CACHE_TTL = 60 * 60 * 24 * 7  # 7 days (prod)

def is_cache_valid(cache_file: Path, ttl: int) -> bool:
    if not cache_file.exists():
        return False
    age = time.time() - cache_file.stat().st_mtime
    return age < ttl

def load_cache(cache_file: Path):
    with cache_file.open("r", encoding="utf-8") as f:
        return json.load(f)

def save_cache(cache_file: Path, data: dict):
    with cache_file.open("w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def fetch_overpass(query: str) -> dict:
    response = requests.get(
        OVERPASS_URL,
        params={"data": query},
        timeout=90,
    )
    response.raise_for_status()
    return response.json()

def get_osm_toilets(
    *,
    use_cache: bool = True,
    force_refresh: bool = False,
) -> dict:
    """
    use_cache=True        → allow cache usage
    force_refresh=True    → bypass cache even if valid
    """

    if use_cache and not force_refresh and is_cache_valid(CACHE_FILE, CACHE_TTL):
        age = int(time.time() - CACHE_FILE.stat().st_mtime)
        print(f"📦 Using cache ({age}s old)")
        return load_cache(CACHE_FILE)

    print("🌍 Fetching toilets from Overpass API…")

    try:
        data = fetch_overpass(OVERPASS_QUERY)
        save_cache(CACHE_FILE, data)
        print(f"✅ Cached {len(data.get('elements', []))} objects")
        return data

    except Exception as e:
        print(f"❌ Overpass error: {e}")

        if CACHE_FILE.exists():
            print("⚠️ Falling back to stale cache")
            return load_cache(CACHE_FILE)

        raise  # no cache to fall back on

# 🚀 Example usage

# Normal dev run (cache enabled)
#osm_data = get_osm_toilets()

# Force refresh (bypass cache)  
osm_data = get_osm_toilets(force_refresh=True)

print(f"🐾 Found {len(osm_data.get('elements', []))} toilets")
# Out:
# 🌍 Fetching toilets from Overpass API…
# ✅ Cached 239 objects
# 🐾 Found 239 toilets

# %%
osm_data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.10 2d4cfc48',
#  'osm3s': {'timestamp_osm_base': '2026-01-25T14:09:30Z',
#   'timestamp_areas_base': '2026-01-23T01:22:35Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 29835248,
#    'lat': 59.3385713,
#    'lon': 18.0553167,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'yes',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 29898114,
#    'lat': 59.3265472,
#    'lon': 18.0844595,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 193906913,
#    'lat': 59.357109,
#    'lon': 18.1031275,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'no',
#     'fee': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 369976531,
#    'lat': 59.3328362,
#    'lon': 18.0753561,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'yes',
#     'fee:price': '5 kr, pissoir free',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 372691861,
#    'lat': 59.3454123,
#    'lon': 18.0721733,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'no',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 410531301,
#    'lat': 59.3374418,
#    'lon': 18.0736794,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2025-08-23',
#     'fee': 'no',
#     'source': 'survey',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 443690836,
#    'lat': 59.3798917,
#    'lon': 17.8171208,
#    'tags': {'amenity': 'toilets', 'check_date': '2023-09-02', 'fee': 'yes'}},
#   {'type': 'node',
#    'id': 445303563,
#    'lat': 59.3304623,
#    'lon': 18.0925901,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2025-08-08',
#     'check_date:wheelchair': '2025-08-08',
#     'fee': 'yes',
#     'source': 'survey',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 445807905,
#    'lat': 59.3695989,
#    'lon': 17.8589297,
#    'tags': {'amenity': 'toilets',
#     'capacity': '5',
#     'capacity:disabled': '1',
#     'note': 'Customers only',
#     'operator': 'Coop',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 446029218,
#    'lat': 59.4024318,
#    'lon': 17.9436104,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'yes',
#     'fee': 'no',
#     'level': '0',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 459815440,
#    'lat': 59.3277084,
#    'lon': 18.1086203,
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'check_date': '2023-09-04',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 477625927,
#    'lat': 59.3300213,
#    'lon': 18.0028746,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 640304865,
#    'lat': 59.3184435,
#    'lon': 18.0623335,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'yes',
#     'check_date': '2025-08-14',
#     'fee': 'no',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 724407721,
#    'lat': 59.3918994,
#    'lon': 17.786176,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 766792010,
#    'lat': 59.3406906,
#    'lon': 18.0427379,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2021-01-08',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 872588195,
#    'lat': 59.285517,
#    'lon': 17.9648209,
#    'tags': {'amenity': 'toilets', 'check_date': '2022-03-28'}},
#   {'type': 'node',
#    'id': 1118901452,
#    'lat': 59.3405711,
#    'lon': 18.0927691,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2022-06-04',
#     'fee': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1209267370,
#    'lat': 59.2990223,
#    'lon': 18.0806817,
#    'tags': {'amenity': 'toilets', 'check_date': '2022-04-15'}},
#   {'type': 'node',
#    'id': 1259515160,
#    'lat': 59.3160928,
#    'lon': 18.0565235,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'check_date': '2024-08-15'}},
#   {'type': 'node',
#    'id': 1281787778,
#    'lat': 59.3472659,
#    'lon': 18.1132343,
#    'tags': {'amenity': 'toilets', 'fee': 'yes', 'name': 'Ica Kvantum'}},
#   {'type': 'node',
#    'id': 1289469921,
#    'lat': 59.3227363,
#    'lon': 18.0691008,
#    'tags': {'amenity': 'toilets', 'fee': 'yes', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1324187530,
#    'lat': 59.271042,
#    'lon': 18.1037297,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 1349576832,
#    'lat': 59.3270502,
#    'lon': 18.0692242,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'yes',
#     'toilets:disposal': 'flush',
#     'toilets:position': 'seated;urinal',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1364657032,
#    'lat': 59.337913,
#    'lon': 18.0610549,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'yes',
#     'check_date': '2020-08-17',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1384929016,
#    'lat': 59.3164495,
#    'lon': 18.0836541,
#    'tags': {'addr:floor': '0',
#     'addr:housenumber': '33',
#     'addr:street': 'Tjärhovsplan',
#     'amenity': 'toilets',
#     'changing_table': 'yes',
#     'check_date': '2024-05-25',
#     'fee': 'no',
#     'level': '0',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1389941075,
#    'lat': 59.3265372,
#    'lon': 18.0950614,
#    'tags': {'access': 'permissive',
#     'amenity': 'toilets',
#     'changing_table': 'yes',
#     'changing_table:location': 'wheelchair_toilet',
#     'check_date': '2023-03-21',
#     'fee': 'no',
#     'level': '1',
#     'operator': 'Wasahamnen',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1424620792,
#    'lat': 59.3241921,
#    'lon': 18.0878097,
#    'tags': {'amenity': 'toilets', 'check_date': '2022-06-06', 'fee': 'yes'}},
#   {'type': 'node',
#    'id': 1424620907,
#    'lat': 59.3271546,
#    'lon': 18.0843116,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2022-06-06',
#     'fee': 'yes',
#     'opening_hours': '24/7',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1425550045,
#    'lat': 59.3266026,
#    'lon': 18.0811277,
#    'tags': {'amenity': 'toilets',
#     'fee': 'yes',
#     'toilets:access': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1432064709,
#    'lat': 59.3368456,
#    'lon': 17.9017216,
#    'tags': {'amenity': 'toilets', 'check_date': '2024-07-17', 'fee': 'no'}},
#   {'type': 'node',
#    'id': 1477922576,
#    'lat': 59.369272,
#    'lon': 18.046575,
#    'tags': {'amenity': 'toilets', 'fee': 'no', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1509877941,
#    'lat': 59.3126655,
#    'lon': 18.0832016,
#    'tags': {'amenity': 'toilets', 'fee': 'yes', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1546340693,
#    'lat': 59.3149548,
#    'lon': 18.0727334,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2024-07-08',
#     'fee': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1605069859,
#    'lat': 59.3470281,
#    'lon': 18.0728861,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2021-12-17',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1716951634,
#    'lat': 59.3392269,
#    'lon': 18.0823327,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2023-09-16',
#     'fee': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1748454774,
#    'lat': 59.3408557,
#    'lon': 18.054234,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2020-02-13',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1760216286,
#    'lat': 59.2982408,
#    'lon': 18.0870863,
#    'tags': {'amenity': 'toilets', 'check_date': '2024-07-28', 'female': 'no'}},
#   {'type': 'node',
#    'id': 1769871680,
#    'lat': 59.3240272,
#    'lon': 18.1014111,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'check_date': '2020-01-27',
#     'fee': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1787546916,
#    'lat': 59.3235136,
#    'lon': 18.0736621,
#    'tags': {'amenity': 'toilets',
#     'charge': '5 SEK',
#     'fee': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1787546986,
#    'lat': 59.3261229,
#    'lon': 18.0730553,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'charge': '5 SEK',
#     'check_date': '2025-06-27',
#     'fee': 'yes',
#     'payment:credit_cards': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1832102620,
#    'lat': 59.3601402,
#    'lon': 18.0544,
#    'tags': {'amenity': 'toilets', 'source': 'survey'}},
#   {'type': 'node',
#    'id': 2171149284,
#    'lat': 59.40289,
#    'lon': 17.9465906,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'no',
#     'female': 'yes',
#     'level': '0',
#     'male': 'yes',
#     'source': 'survey',
#     'toilets:disposal': 'flush',
#     'toilets:hands_drying': 'electric_hand_dryer',
#     'toilets:handwashing': 'yes',
#     'toilets:paper_supplied': 'yes',
#     'toilets:position': 'seated',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2189008509,
#    'lat': 59.2769001,
#    'lon': 17.9095426,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2024-04-07',
#     'fee': 'yes',
#     'note': 'Pissoar gratis'}},
#   {'type': 'node',
#    'id': 2346958852,
#    'lat': 59.3273358,
#    'lon': 18.0548932,
#    'tags': {'amenity': 'toilets',
#     'check_date:opening_hours': '2024-07-19',
#     'fee': 'no',
#     'level': '0',
#     'opening_hours': 'Mo-Su 08:00-17:30',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2396254046,
#    'lat': 59.2977354,
#    'lon': 18.0812461,
#    'tags': {'amenity': 'toilets', 'fee': 'no', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2396254047,
#    'lat': 59.2943285,
#    'lon': 18.0788342,
#    'tags': {'amenity': 'toilets', 'check_date': '2023-11-26', 'fee': 'yes'}},
#   {'type': 'node',
#    'id': 2415157851,
#    'lat': 59.33096,
#    'lon': 18.1324557,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'yes',
#     'fee': 'yes',
#     'payment:cash': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2494165898,
#    'lat': 59.330459,
#    'lon': 18.0580965,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'yes',
#     'check_date': '2025-01-17',
#     'fee': 'yes',
#     'gender_segregated': 'no',
#     'level': '-1',
#     'opening_hours': 'Mo-Fr 05:00-01:15; Sa,Su 05:00-02:15',
#     'operator': 'Rena sitsen',
#     'supervised': 'yes',
#     'toilets:handwashing': 'yes',
#     'toilets:paper_supplied': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2560497582,
#    'lat': 59.2631508,
#    'lon': 18.0428652,
#    'tags': {'amenity': 'toilets', 'check_date': '2021-08-19'}},
#   {'type': 'node',
#    'id': 2571793279,
#    'lat': 59.3389029,
#    'lon': 17.9386297,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'yes',
#     'check_date': '2023-09-09',
#     'fee': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2933323739,
#    'lat': 59.2942832,
#    'lon': 17.9763444,
#    'tags': {'access': 'yes', 'amenity': 'toilets', 'fee': 'no'}},
#   {'type': 'node',
#    'id': 3200776743,
#    'lat': 59.2949245,
#    'lon': 18.1023825,
#    'tags': {'access': 'yes', 'amenity': 'toilets', 'opening_hours': '24/7'}},
#   {'type': 'node',
#    'id': 3476960950,
#    'lat': 59.3828077,
#    'lon': 17.8993744,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2025-09-01',
#     'check_date:wheelchair': '2025-09-01',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3632143752,
#    'lat': 59.2531117,
#    'lon': 18.1616127,
#    'tags': {'amenity': 'toilets', 'name': 'Toaletter, omklädnad, dusch'}},
#   {'type': 'node',
#    'id': 3635154983,
#    'lat': 59.331521,
#    'lon': 18.0952261,
#    'tags': {'access': 'customers', 'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 3635588044,
#    'lat': 59.3275435,
#    'lon': 18.1157935,
#    'tags': {'access': 'yes',
#     'addr:housenumber': '12',
#     'addr:street': 'Rosendalsterrassen',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'check_date': '2024-04-27',
#     'ele': '21.63',
#     'fee': 'no',
#     'opening_hours': '11:00-16:00',
#     'source': 'survey',
#     'toilets:disposal': 'flush',
#     'toilets:handwashing': 'yes',
#     'toilets:position': 'seated;urinal',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3723792937,
#    'lat': 59.2835544,
#    'lon': 18.1149817,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 4033757299,
#    'lat': 59.3310046,
#    'lon': 18.0725238,
#    'tags': {'amenity': 'toilets',
#     'fee': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'toilets:position': 'seated',
#     'unisex': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 4254524923,
#    'lat': 59.2788208,
#    'lon': 18.0089877,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'yes',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 4368041862,
#    'lat': 59.3334473,
#    'lon': 18.0857733,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'drinking_water': 'seasonal',
#     'female': 'yes',
#     'male': 'yes',
#     'name': 'Östermalms cykelservice HB',
#     'phone': '+46-8-6608809',
#     'service:bicycle:cleaning': 'no',
#     'service:bicycle:rental': 'no',
#     'service:bicycle:repair': 'yes',
#     'service:bicycle:retail': 'no',
#     'service:bicycle:second_hand': 'no',
#     'shop': 'bicycle',
#     'toilets:disposal': 'chemical',
#     'toilets:position': 'squat',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 4732653749,
#    'lat': 59.2979917,
#    'lon': 17.9969603,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'yes',
#     'check_date': '2023-04-07',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 4866592761,
#    'lat': 59.297128,
#    'lon': 18.050931,
#    'tags': {'amenity': 'toilets', 'fee': 'no', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 4917115048,
#    'lat': 59.3260654,
#    'lon': 18.0703524,
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'changing_table': 'yes',
#     'check_date': '2025-10-28',
#     'check_date:opening_hours': '2025-10-28',
#     'fee': 'yes',
#     'opening_hours': 'Mo-Su 10:00-16:00',
#     'toilets:disposal': 'flush',
#     'toilets:position': 'seated;urinal',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 4917115049,
#    'lat': 59.3266428,
#    'lon': 18.0729595,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 5030242913,
#    'lat': 59.3316737,
#    'lon': 18.0423961,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'fee': 'no',
#     'male': 'yes',
#     'toilets:disposal': 'pitlatrine'}},
#   {'type': 'node',
#    'id': 5139444472,
#    'lat': 59.3231513,
#    'lon': 18.0754401,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'charge': '5sek',
#     'check_date': '2025-09-02',
#     'fee': 'yes',
#     'fixme': 'Pissoir is free. Not sure how this can be mapped',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 5139444482,
#    'lat': 59.3254053,
#    'lon': 18.0758963,
#    'tags': {'amenity': 'toilets', 'fee': 'no', 'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 5168944621,
#    'lat': 59.3076416,
#    'lon': 18.0285424,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'yes',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 5320545219,
#    'lat': 59.3272194,
#    'lon': 18.0992781,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 5417312399,
#    'lat': 59.3629862,
#    'lon': 17.9474919,
#    'tags': {'amenity': 'toilets', 'fee': 'no', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 5574707149,
#    'lat': 59.3255001,
#    'lon': 18.1006354,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'check_date': '2024-07-27',
#     'unisex': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 5641916262,
#    'lat': 59.3476185,
#    'lon': 18.0732067,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'no',
#     'check_date': '2025-01-26',
#     'fee': 'no',
#     'female': 'no',
#     'male': 'yes',
#     'toilets:disposal': 'flush',
#     'toilets:position': 'seated;urinal'}},
#   {'type': 'node',
#    'id': 5641916263,
#    'lat': 59.3479754,
#    'lon': 18.0717395,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'no',
#     'fee': 'no',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes'}},
#   {'type': 'node',
#    'id': 5641916264,
#    'lat': 59.3485703,
#    'lon': 18.0740784,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2026-01-07',
#     'fee': 'no',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 5747554078,
#    'lat': 59.3126652,
#    'lon': 18.0527684,
#    'tags': {'amenity': 'toilets', 'male': 'yes', 'toilets:disposal': 'flush'}},
#   {'type': 'node',
#    'id': 5869178329,
#    'lat': 59.3242388,
#    'lon': 18.0634683,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'no',
#     'fee': 'yes',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 5869178330,
#    'lat': 59.3242593,
#    'lon': 18.0633939,
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'male': 'yes',
#     'toilets:disposal': 'flush',
#     'toilets:position': 'urinal',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 5872319885,
#    'lat': 59.313856,
#    'lon': 18.0809232,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'fee': 'no',
#     'male': 'yes',
#     'toilets:disposal': 'flush',
#     'toilets:position': 'urinal',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 5908739999,
#    'lat': 59.3401314,
#    'lon': 18.0904825,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'capacity': '5',
#     'capacity:disabled': '1',
#     'changing_table': 'yes',
#     'changing_table:count': '1',
#     'changing_table:location': 'wheelchair_toilet',
#     'fee': 'yes',
#     'level': '0',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa 08:00-18:00; Su 08:00-17:00',
#     'supervised': 'yes',
#     'toilets:disposal': 'flush',
#     'toilets:position': 'seated',
#     'unisex': 'yes',
#     'wheelchair': 'designated'}},
#   {'type': 'node',
#    'id': 6147685283,
#    'lat': 59.3227974,
#    'lon': 18.0954155,
#    'tags': {'amenity': 'toilets', 'fee': 'no', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 6147685284,
#    'lat': 59.3228676,
#    'lon': 18.0958632,
#    'tags': {'amenity': 'toilets', 'fee': 'no', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 6147685285,
#    'lat': 59.3231806,
#    'lon': 18.095223,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 6147685303,
#    'lat': 59.324353,
#    'lon': 18.0966908,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 6147685311,
#    'lat': 59.3241665,
#    'lon': 18.0976996,
#    'tags': {'amenity': 'toilets', 'check_date': '2025-05-10'}},
#   {'type': 'node',
#    'id': 6147685312,
#    'lat': 59.3236424,
#    'lon': 18.0984185,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 6278191866,
#    'lat': 59.301543,
#    'lon': 18.016525,
#    'tags': {'amenity': 'toilets', 'male': 'yes'}},
#   {'type': 'node',
#    'id': 6530497216,
#    'lat': 59.3128575,
#    'lon': 18.0114838,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 6582489844,
#    'lat': 59.3276705,
#    'lon': 18.1029567,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 6806048085,
#    'lat': 59.2704369,
#    'lon': 18.1029328,
#    'tags': {'amenity': 'toilets', 'fee': 'no', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 6821142528,
#    'lat': 59.2749357,
#    'lon': 18.1029444,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2024-10-24',
#     'check_date:wheelchair': '2024-10-24',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 6886797350,
#    'lat': 59.2925405,
#    'lon': 18.0821989,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'no',
#     'opening_hours': 'Mo-Fr 08:00-19:15; Sa 08:30-17:15; Su 09:30-17:15',
#     'toilets:disposal': 'flush',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 6925333754,
#    'lat': 59.3371,
#    'lon': 18.0102,
#    'tags': {'amenity': 'toilets',
#     'capacity': '3',
#     'fee': 'no',
#     'level': '5',
#     'name': 'WC Lindhagen',
#     'opening_hours': 'Mo-Su 10:00-20:45',
#     'toilets:disposal': 'flush',
#     'toilets:position': 'seated'}},
#   {'type': 'node',
#    'id': 6925458516,
#    'lat': 59.3371989,
#    'lon': 18.0100597,
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'description': 'vid kassorna i ica',
#     'level': '3'}},
#   {'type': 'node',
#    'id': 6978060187,
#    'lat': 59.3321748,
#    'lon': 18.0631523,
#    'tags': {'amenity': 'toilets',
#     'check_date:opening_hours': '2024-08-07',
#     'fee': 'yes',
#     'level': '-1',
#     'opening_hours': 'Mo-Fr 08:30-22:30; Sa 09:00-22:30; Su 10:00-22:30',
#     'supervised': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 7080294643,
#    'lat': 59.339345,
#    'lon': 18.0911149,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'capacity': '3',
#     'charge': '10 SEK',
#     'fee': 'yes',
#     'level': '0',
#     'opening_hours': 'Mo-Fr 09:00-20:00; Sa 09:00-18:00; Su 09:00-17:00'}},
#   {'type': 'node',
#    'id': 7081966216,
#    'lat': 59.3274169,
#    'lon': 18.0995017,
#    'tags': {'access': 'customers', 'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 7083910043,
#    'lat': 59.3443965,
#    'lon': 18.0766991,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'check_date': '2019-12-25',
#     'fee': 'no',
#     'female': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 7099633419,
#    'lat': 59.3193132,
#    'lon': 18.0313808,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'no',
#     'male': 'yes',
#     'toilets:position': 'urinal',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 7112447493,
#    'lat': 59.3558766,
#    'lon': 17.9556966,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'yes',
#     'check_date': '2025-01-03',
#     'fee': 'no',
#     'level': '-1',
#     'toilets:disposal': 'flush',
#     'toilets:handwashing': 'yes',
#     'toilets:paper_supplied': 'yes',
#     'toilets:position': 'seated',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 7153971973,
#    'lat': 59.3397514,
#    'lon': 18.0427592,
#    'tags': {'access': 'permissive',
#     'amenity': 'toilets',
#     'check_date': '2023-06-26',
#     'description': 'Open when café is open',
#     'fee': 'no'}},
#   {'type': 'node',
#    'id': 7164301785,
#    'lat': 59.3244529,
#    'lon': 18.101685,
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'changing_table': 'yes',
#     'check_date': '2025-04-17',
#     'check_date:wheelchair': '2025-04-17',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 7164786478,
#    'lat': 59.3276831,
#    'lon': 18.1083196,
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'check_date': '2020-01-27',
#     'wheelchair': 'designated'}},
#   {'type': 'node',
#    'id': 7165983806,
#    'lat': 59.3398522,
#    'lon': 18.0470559,
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'check_date': '2023-03-22',
#     'fee': 'yes'}},
#   {'type': 'node',
#    'id': 7182346054,
#    'lat': 59.3320424,
#    'lon': 18.118511,
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'check_date': '2020-02-03',
#     'indoor': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 7227587405,
#    'lat': 59.2937471,
#    'lon': 17.9083309,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 7272659591,
#    'lat': 59.3273058,
#    'lon': 18.106561,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'check_date': '2020-03-06'}},
#   {'type': 'node',
#    'id': 7280528437,
#    'lat': 59.3349,
#    'lon': 18.0324,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'yes',
#     'opening_hours': 'Sa 11:00-16:00; Mo-Fr 11:00-18:00; Su 12:00-16:00',
#     'payment:credit_cards': 'yes',
#     'payment:swish': 'yes',
#     'supervised': 'yes',
#     'toilets:handwashing': 'yes',
#     'toilets:paper_supplied': 'yes'}},
#   {'type': 'node',
#    'id': 7294234246,
#    'lat': 59.3177269,
#    'lon': 18.0506386,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'yes',
#     'fee': 'yes',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 7296559329,
#    'lat': 59.3325442,
#    'lon': 18.0621915,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'yes',
#     'gender_segregated': 'no',
#     'level': '2',
#     'operator': 'Åhlens',
#     'supervised': 'yes',
#     'toilets:handwashing': 'yes',
#     'toilets:paper_supplied': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 7319718731,
#    'lat': 59.3369703,
#    'lon': 17.9036251,
#    'tags': {'amenity': 'toilets', 'fee': 'no', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 7557292742,
#    'lat': 59.253589,
#    'lon': 18.0772901,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'no',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 7569482686,
#    'lat': 59.2961937,
#    'lon': 18.0595096,
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'survey:date': '2020-05-29',
#     'undefined': 'unisex',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 7597644699,
#    'lat': 59.2464907,
#    'lon': 18.1091214,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 7600913845,
#    'lat': 59.2763112,
#    'lon': 18.1309732,
#    'tags': {'access': 'yes', 'amenity': 'toilets', 'fee': 'no'}},
#   {'type': 'node',
#    'id': 7648727537,
#    'lat': 59.2371009,
#    'lon': 18.0859725,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 7657261625,
#    'lat': 59.2492114,
#    'lon': 18.1268993,
#    'tags': {'amenity': 'toilets',
#     'toilets:disposal': 'bucket',
#     'unisex': 'yes'}},
#   {'type': 'node',
#    'id': 7658289965,
#    'lat': 59.2585966,
#    'lon': 18.0831423,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'fee': 'no',
#     'male': 'yes',
#     'name': 'Urinoar',
#     'toilets:handwashing': 'no'}},
#   {'type': 'node',
#    'id': 7658292704,
#    'lat': 59.257867,
#    'lon': 18.0818062,
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'toilets:disposal': 'flush',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 7681253886,
#    'lat': 59.2487688,
#    'lon': 18.1204842,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'toilets:disposal': 'bucket',
#     'unisex': 'yes'}},
#   {'type': 'node',
#    'id': 7928661244,
#    'lat': 59.2792099,
#    'lon': 18.0951571,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 7928755500,
#    'lat': 59.2966808,
#    'lon': 17.9315929,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 8243569652,
#    'lat': 59.3283732,
#    'lon': 18.0237391,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'no',
#     'indoor': 'yes',
#     'operator': 'Rålambshovsparken Parklek'}},
#   {'type': 'node',
#    'id': 8492972309,
#    'lat': 59.360709,
#    'lon': 17.8821402,
#    'tags': {'amenity': 'toilets', 'unisex': 'yes'}},
#   {'type': 'node',
#    'id': 8587809280,
#    'lat': 59.3425063,
#    'lon': 18.0488858,
#    'tags': {'amenity': 'toilets', 'fee': 'no', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 8622427653,
#    'lat': 59.3622437,
#    'lon': 17.8721592,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 8622720147,
#    'lat': 59.3615667,
#    'lon': 17.875294,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 8661970179,
#    'lat': 59.3118737,
#    'lon': 18.0761832,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'fee': 'no',
#     'male': 'yes',
#     'toilets:disposal': 'pitlatrine',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 8911378390,
#    'lat': 59.3351193,
#    'lon': 18.0626386,
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'operator': 'Konserthuset Stockholm',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 9019946772,
#    'lat': 59.2663653,
#    'lon': 18.0478969,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'portable': 'yes',
#     'toilets:disposal': 'chemical',
#     'toilets:handwashing': 'no',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 9025836735,
#    'lat': 59.324787,
#    'lon': 18.1047908,
#    'tags': {'access': 'customers', 'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 9083726951,
#    'lat': 59.3221449,
#    'lon': 18.1251051,
#    'tags': {'amenity': 'toilets', 'fee': 'yes'}},
#   {'type': 'node',
#    'id': 9382082948,
#    'lat': 59.3319131,
#    'lon': 18.0646498,
#    'tags': {'amenity': 'toilets',
#     'charge': '10',
#     'check_date': '2023-02-11',
#     'fee': 'yes',
#     'name': 'WC kulturhuset'}},
#   {'type': 'node',
#    'id': 9646896909,
#    'lat': 59.3275883,
#    'lon': 18.0342918,
#    'tags': {'access': 'customers', 'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 9646923631,
#    'lat': 59.3272907,
#    'lon': 18.0341735,
#    'tags': {'access': 'customers', 'amenity': 'toilets', 'level': '-1'}},
#   {'type': 'node',
#    'id': 9668335573,
#    'lat': 59.329541,
#    'lon': 18.1188575,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'no',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 9748210746,
#    'lat': 59.3314481,
#    'lon': 18.0039889,
#    'tags': {'access': 'yes', 'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 9769321976,
#    'lat': 59.3173498,
#    'lon': 18.0870611,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'charge': '50 SEK',
#     'fee': 'yes',
#     'payment:cash': 'no',
#     'payment:visa': 'yes'}},
#   {'type': 'node',
#    'id': 9784891345,
#    'lat': 59.3182573,
#    'lon': 18.0753998,
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 9788137253,
#    'lat': 59.3278909,
#    'lon': 18.0579709,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'yes',
#     'female': 'yes',
#     'male': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 9791329094,
#    'lat': 59.3887619,
#    'lon': 17.9261202,
#    'tags': {'amenity': 'toilets', 'fee': 'yes'}},
#   {'type': 'node',
#    'id': 9872583661,
#    'lat': 59.3301711,
#    'lon': 18.067426,
#    'tags': {'amenity': 'toilets',
#     'check_date': '2024-01-27',
#     'fee': 'yes',
#     'level': '0',
#     'operator': 'One Hundred Restrooms',
#     'supervised': 'yes',
#     'toilets:disposal': 'flush',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 9922555009,
#    'lat': 59.327034,
#    'lon': 18.1072607,
#    'tags': {'amenity': 'toilets', 'fee': 'no'}},
#   {'type': 'node',
#    'id': 9955035548,
#    'lat': 59.3221113,
#    'lon': 17.9842101,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'fee': 'no',
#     'toilets:disposal': 'chemical',
#     'unisex': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 10172419501,
#    'lat': 59.2701073,
#    'lon': 18.0495879,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'male': 'yes',
#     'toilets:handwashing': 'no',
#     'toilets:position': 'urinal'}},
#   {'type': 'node',
#    'id': 10180723346,
#    'lat': 59.3296703,
#    'lon': 18.0927131,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'description': 'Almänna toaletter',
#     'description:en': 'Public toilets',
#     'fee': 'yes'}},
#   {'type': 'node',
#    'id': 10189302015,
#    'lat': 59.3083799,
#    'lon': 18.0755806,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'check_date': '2022-11-16',
#     'fee': 'yes',
#     'level': '-1',
#     'name': 'Wc Ringen',
#     'opening_hours': 'Mo-Th 08:00-21:30; Fr 08:00-22:30; Sa 10:00-22:30; Su 11:00-20:30',
#     'supervised': 'yes',
#     'toilets:handwashing': 'yes',
#     'toilets:paper_supplied': 'yes'}},
#   {'type': 'node',
#    'id': 10199655164,
#    'lat': 59.3093967,
#    'lon': 18.0222658,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'yes',
#     'gender_segregated': 'no',
#     'level': '1',
#     'operator': 'One Hundred Restrooms',
#     'supervised': 'yes',
#     'toilets:handwashing': 'yes',
#     'toilets:paper_supplied': 'yes'}},
#   {'type': 'node',
#    'id': 10539845974,
#    'lat': 59.3515122,
#    'lon': 18.1115202,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'no',
#     'layer': '1',
#     'level': '1',
#     'opening_hours': '08:30-17:30; May 01-Sep 03 05:45-17:30'}},
#   {'type': 'node',
#    'id': 10677197219,
#    'lat': 59.321739,
#    'lon': 17.9932247,
#    'tags': {'amenity': 'toilets', 'portable': 'yes'}},
#   {'type': 'node',
#    'id': 11065469183,
#    'lat': 59.3249815,
#    'lon': 18.096313,
#    'tags': {'access': 'permissive',
#     'amenity': 'toilets',
#     'check_date': '2023-07-23',
#     'fee': 'no',
#     'level': '0',
#     'unisex': 'yes'}},
#   {'type': 'node',
#    'id': 11067741049,
#    'lat': 59.335769,
#    'lon': 18.078065,
#    'tags': {'amenity': 'toilets',
#     'charge': '5 SEK',
#     'fee': 'yes',
#     'level': '-1',
#     'payment:cash': 'no',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes'}},
#   {'type': 'node',
#    'id': 11068832663,
#    'lat': 59.3619347,
#    'lon': 18.0491424,
#    'tags': {'amenity': 'toilets',
#     'name': 'Toalett - WC - Brunnsvikens strandbad',
#     'operator': 'Stockholms stad',
#     'toilets:disposal': 'chemical'}},
#   {'type': 'node',
#    'id': 11299877671,
#    'lat': 59.3310312,
#    'lon': 18.0725081,
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'male': 'yes',
#     'toilets:position': 'urinal',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 11323242669,
#    'lat': 59.3077197,
#    'lon': 17.9949481,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'yes',
#     'fee': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 11606322450,
#    'lat': 59.2534485,
#    'lon': 18.0660197,
#    'tags': {'access': 'yes', 'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 11675221753,
#    'lat': 59.2706553,
#    'lon': 18.1489478,
#    'tags': {'amenity': 'toilets', 'male': 'yes', 'source': 'local knowledge'}},
#   {'type': 'node',
#    'id': 11675221754,
#    'lat': 59.2706327,
#    'lon': 18.1488407,
#    'tags': {'amenity': 'toilets',
#     'female': 'yes',
#     'source': 'local knowledge'}},
#   {'type': 'node',
#    'id': 11868306928,
#    'lat': 59.3148427,
#    'lon': 18.0691925,
#    'tags': {'access': 'yes',
#     'addr:floor': '0',
#     'amenity': 'toilets',
#     'charge': '10 SEK',
#     'check_date': '2024-07-18',
#     'fee': 'yes',
#     'level': '0',
#     'opening_hours': '24/7',
#     'payment:cards': 'yes',
#     'payment:credit_cards': 'yes',
#     'toilets:disposal': 'flush',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12057146146,
#    'lat': 59.368835,
#    'lon': 18.0538555,
#    'tags': {'amenity': 'toilets', 'check_date': '2024-07-16', 'level': '3'}},
#   {'type': 'node',
#    'id': 12060906958,
#    'lat': 59.3486326,
#    'lon': 17.9014674,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'changing_table': 'no',
#     'check_date': '2024-07-18',
#     'toilets:disposal': 'flush',
#     'toilets:handwashing': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12066966838,
#    'lat': 59.3283968,
#    'lon': 18.0779797,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'yes',
#     'check_date': '2025-05-01',
#     'fee': 'no',
#     'level': '-1',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12102894384,
#    'lat': 59.3305837,
#    'lon': 18.0710063,
#    'tags': {'access': 'yes', 'amenity': 'toilets', 'fee': 'yes'}},
#   {'type': 'node',
#    'id': 12146805046,
#    'lat': 59.2692357,
#    'lon': 18.1019018,
#    'tags': {'amenity': 'toilets',
#     'female': 'yes',
#     'male': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12192854100,
#    'lat': 59.333055,
#    'lon': 18.1187637,
#    'tags': {'access': 'customers', 'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 12264532458,
#    'lat': 59.3311839,
#    'lon': 18.061056,
#    'tags': {'access': 'customers', 'amenity': 'toilets', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12284615881,
#    'lat': 59.3381211,
#    'lon': 18.0019279,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 12288430701,
#    'lat': 59.3153967,
#    'lon': 18.0713619,
#    'tags': {'amenity': 'toilets', 'fee': 'no'}},
#   {'type': 'node',
#    'id': 12473659398,
#    'lat': 59.3357949,
#    'lon': 18.0775376,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'yes',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12765641884,
#    'lat': 59.3076743,
#    'lon': 17.9949064,
#    'tags': {'amenity': 'toilets',
#     'changing_table': 'yes',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12801920135,
#    'lat': 59.3314715,
#    'lon': 18.0677919,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'check_date': '2025-05-01',
#     'fee': 'yes',
#     'level': '-1',
#     'toilets:disposal': 'flush'}},
#   {'type': 'node',
#    'id': 13039325601,
#    'lat': 59.3301735,
#    'lon': 18.0576826,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 13051824942,
#    'lat': 59.2784219,
#    'lon': 18.0110944,
#    'tags': {'amenity': 'toilets',
#     'fee': 'yes',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 13058272701,
#    'lat': 59.3276578,
#    'lon': 18.1154601,
#    'tags': {'addr:housenumber': '12',
#     'addr:street': 'Rosendalsterrassen',
#     'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 13074482684,
#    'lat': 59.3622164,
#    'lon': 17.8725855,
#    'tags': {'access': 'unknown',
#     'amenity': 'toilets',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 13078318901,
#    'lat': 59.3305991,
#    'lon': 18.0934575,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 13094500201,
#    'lat': 59.2926053,
#    'lon': 18.0839742,
#    'tags': {'addr:housenumber': '7',
#     'addr:street': 'Arenaslingan',
#     'amenity': 'toilets',
#     'opening_hours': '24/7'}},
#   {'type': 'node',
#    'id': 13176341120,
#    'lat': 59.2724331,
#    'lon': 17.8805595,
#    'tags': {'amenity': 'toilets'}},
#   {'type': 'node',
#    'id': 13255537816,
#    'lat': 59.3139975,
#    'lon': 18.0637586,
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'charge': '10 SEK',
#     'check_date': '2025-10-25',
#     'fee': 'yes',
#     'toilets:disposal': 'flush',
#     'toilets:handwashing': 'yes',
#     'toilets:position': 'seated'}},
#   {'type': 'node',
#    'id': 13432470449,
#    'lat': 59.3309051,
#    'lon': 18.0596305,
#    'tags': {'amenity': 'toilets',
#     'fee': 'yes',
#     'indoor': 'yes',
#     'level': '-1',
#     'location': 'underground'}},
#   {'type': 'way',
#    'id': 117573214,
#    'center': {'lat': 59.2769299, 'lon': 18.1008204},
#    'nodes': [1324273938,
#     1324273820,
#     1324273819,
#     1324273823,
#     1324273825,
#     1324273821,
#     1324273824,
#     1324273871,
#     1324273846,
#     1324273938],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'opening_hours': 'Mo-Su 09:00-18:00',
#     'toilets:disposal': 'flush',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 124973325,
#    'center': {'lat': 59.3256748, 'lon': 18.021344},
#    'nodes': [1389264561, 1389264485, 1389264524, 1389264570, 1389264561],
#    'tags': {'amenity': 'toilets',
#     'building': 'toilets',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 125085090,
#    'center': {'lat': 59.2999258, 'lon': 17.9265032},
#    'nodes': [1390114337, 1390114351, 1390114334, 1390114308, 1390114337],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'supervised': 'no'}},
#   {'type': 'way',
#    'id': 126084738,
#    'center': {'lat': 59.2867894, 'lon': 17.8934717},
#    'nodes': [1398678935, 1398678789, 1398678947, 1398678933, 1398678935],
#    'tags': {'amenity': 'toilets', 'building': 'yes'}},
#   {'type': 'way',
#    'id': 127586369,
#    'center': {'lat': 59.3325628, 'lon': 18.0336794},
#    'nodes': [1411730595,
#     1411730593,
#     1411730592,
#     1411730594,
#     1411730596,
#     1411730597,
#     1411730599,
#     1411730602,
#     1411730601,
#     1411730600,
#     1411730598,
#     1411730595],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'changing_table': 'no',
#     'check_date': '2020-06-13',
#     'fee': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'way',
#    'id': 139407909,
#    'center': {'lat': 59.3221565, 'lon': 18.1141505},
#    'nodes': [1528432436, 1528432435, 1528432443, 1528432446, 1528432436],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'yes',
#     'opening_hours': 'Mo-Su 11:00-17:00',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 141416395,
#    'center': {'lat': 59.3265095, 'lon': 18.1021664},
#    'nodes': [1547913080,
#     1547913118,
#     1547913021,
#     9655374231,
#     1547913196,
#     1547913080],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'changing_table': 'yes',
#     'fee': 'no',
#     'source': 'bing',
#     'wheelchair': 'no'}},
#   {'type': 'way',
#    'id': 196339041,
#    'center': {'lat': 59.2737283, 'lon': 18.1027006},
#    'nodes': [2066792636,
#     2066792688,
#     2066792713,
#     2066792692,
#     2066803926,
#     2066792636],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'name': 'Väntrum & toalett',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 310373529,
#    'center': {'lat': 59.3075079, 'lon': 17.9600832},
#    'nodes': [3157940322, 3157940323, 3157940324, 3157940325, 3157940322],
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes'}},
#   {'type': 'way',
#    'id': 429821933,
#    'center': {'lat': 59.3474559, 'lon': 17.8839878},
#    'nodes': [4290227923, 4290227924, 4290227925, 4290227926, 4290227923],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 468729960,
#    'center': {'lat': 59.2941955, 'lon': 17.9697643},
#    'nodes': [4632047260, 4632047261, 4632047262, 4632047263, 4632047260],
#    'tags': {'access': 'permissive', 'amenity': 'toilets', 'building': 'yes'}},
#   {'type': 'way',
#    'id': 506545966,
#    'center': {'lat': 59.3230547, 'lon': 18.1468022},
#    'nodes': [4962602358, 4962602356, 4962602357, 4962602361, 4962602358],
#    'tags': {'amenity': 'toilets', 'building': 'yes', 'fee': 'yes'}},
#   {'type': 'way',
#    'id': 524772827,
#    'center': {'lat': 59.3330191, 'lon': 17.9801396},
#    'nodes': [5106278632, 5106278633, 5106278634, 5106278635, 5106278632],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 530012600,
#    'center': {'lat': 59.3245876, 'lon': 18.0958092},
#    'nodes': [5147750231, 5147750229, 5147750228, 5147750230, 5147750231],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'changing_table': 'yes',
#     'fee': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 617586351,
#    'center': {'lat': 59.3203908, 'lon': 18.0324437},
#    'nodes': [5837957145, 5837957146, 5837957147, 5837957148, 5837957145],
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'operator': 'Langholmens Husbilcamoping',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'way',
#    'id': 617586353,
#    'center': {'lat': 59.320398, 'lon': 18.032793},
#    'nodes': [5837957149, 5837957150, 5837957151, 5837957152, 5837957149],
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'operator': 'Langholems Husbilcamping',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'way',
#    'id': 666327988,
#    'center': {'lat': 59.3250442, 'lon': 18.1058772},
#    'nodes': [6238323028, 6238323029, 6238323027, 6238323031, 6238323028],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'building:colour': 'red',
#     'building:levels': '1',
#     'height': '2',
#     'roof:height': '0',
#     'wikidata': 'Q60721297',
#     'wikimedia_commons': 'Category:Uthuset, Statarlängan, Skansen'}},
#   {'type': 'way',
#    'id': 672253208,
#    'center': {'lat': 59.3690698, 'lon': 18.0433731},
#    'nodes': [6295176203, 6295176202, 6295176201, 6295176200, 6295176203],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 681658274,
#    'center': {'lat': 59.3017587, 'lon': 18.0062001},
#    'nodes': [6383728195,
#     6383728194,
#     6383728193,
#     9814455204,
#     6383728192,
#     6383728195],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'yes',
#     'toilets:disposal': 'flush'}},
#   {'type': 'way',
#    'id': 730129060,
#    'center': {'lat': 59.3528953, 'lon': 18.0480535},
#    'nodes': [6839906393, 6839906394, 6839906395, 6839906396, 6839906393],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'changing_table': 'yes',
#     'fee': 'no',
#     'unisex': 'yes'}},
#   {'type': 'way',
#    'id': 750264955,
#    'center': {'lat': 59.3422324, 'lon': 18.0567025},
#    'nodes': [7015294718, 7015294720, 7015294719, 7015294721, 7015294718],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'shed',
#     'changing_table': 'yes',
#     'check_date': '2020-02-02',
#     'fee': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 808189284,
#    'center': {'lat': 59.253581, 'lon': 18.0772925},
#    'nodes': [7557292738, 7557292739, 7557292740, 7557292741, 7557292738],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 811198689,
#    'center': {'lat': 59.3073781, 'lon': 17.961624},
#    'nodes': [7582816287, 7582816286, 7582816285, 7582214484, 7582816287],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'toilets:disposal': 'flush',
#     'toilets:handwashing': 'yes',
#     'unisex': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'way',
#    'id': 822568807,
#    'center': {'lat': 59.3042226, 'lon': 18.0710762},
#    'nodes': [7680484091, 7680484090, 7680484092, 7680484089, 7680484091],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'toilets:disposal': 'flush',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 825794982,
#    'center': {'lat': 59.3726365, 'lon': 18.0685774},
#    'nodes': [7710352295, 7710352296, 7710352297, 7710352298, 7710352295],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'toilets:disposal': 'chemical',
#     'toilets:handwashing:hand_disinfection': 'yes',
#     'unisex': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'way',
#    'id': 870347319,
#    'center': {'lat': 59.3127281, 'lon': 18.0381509},
#    'nodes': [8108201247,
#     8108201237,
#     8108201236,
#     8108201246,
#     8108201245,
#     8108201238,
#     8108201239,
#     8108201244,
#     8108201247],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'check_date': '2024-05-24',
#     'fee': 'no',
#     'toilets:disposal': 'flush',
#     'toilets:hands_drying': 'electric_hand_dryer',
#     'toilets:handwashing': 'yes',
#     'toilets:paper_supplied': 'yes',
#     'toilets:position': 'seated;urinal',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 970988546,
#    'center': {'lat': 59.3217693, 'lon': 18.0250792},
#    'nodes': [8986446906, 8986446903, 8986446904, 8986446905, 8986446906],
#    'tags': {'amenity': 'toilets',
#     'building': 'toilets',
#     'building:levels': '1',
#     'check_date': '2020-08-08',
#     'fee': 'no',
#     'female': 'yes',
#     'male': 'yes',
#     'toilets:position': 'seated;urinal',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 978650033,
#    'center': {'lat': 59.3371345, 'lon': 17.8970534},
#    'nodes': [9055431519,
#     9055431520,
#     9055431521,
#     9055431522,
#     9055431523,
#     9055431524,
#     9055431519],
#    'tags': {'amenity': 'toilets', 'building': 'yes'}},
#   {'type': 'way',
#    'id': 979816263,
#    'center': {'lat': 59.2593037, 'lon': 18.0199944},
#    'nodes': [9064061604, 9064061605, 9064061606, 9064061607, 9064061604],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 984902214,
#    'center': {'lat': 59.3116135, 'lon': 18.0912046},
#    'nodes': [9105581526, 9105581525, 9105581524, 9105581523, 9105581526],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 1027045701,
#    'center': {'lat': 59.3268902, 'lon': 18.0524919},
#    'nodes': [9468847029, 9468847028, 9468847027, 9468847026, 9468847029],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'check_date': '2024-05-26',
#     'fee': 'no',
#     'supervised': 'no',
#     'toilets:disposal': 'flush',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 1029046638,
#    'center': {'lat': 59.3548906, 'lon': 18.0978461},
#    'nodes': [9487421809,
#     11771354596,
#     9487421810,
#     9487421811,
#     10703909920,
#     9487421809],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'fee': 'no',
#     'layer': '1',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 1051596459,
#    'center': {'lat': 59.3349623, 'lon': 18.0553192},
#    'nodes': [9663829979, 9663829978, 9663829977, 9663829976, 9663829979],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'changing_table': 'yes',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 1068141312,
#    'center': {'lat': 59.3644976, 'lon': 18.0713001},
#    'nodes': [9805727806, 9805727807, 9805727808, 9805727809, 9805727806],
#    'tags': {'amenity': 'toilets', 'building': 'yes'}},
#   {'type': 'way',
#    'id': 1113183440,
#    'center': {'lat': 59.3280017, 'lon': 18.0260127},
#    'nodes': [10184589906,
#     10184589907,
#     10184589908,
#     10184603743,
#     10184589909,
#     10184589906],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'check_date': '2021-08-05',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 1161056574,
#    'center': {'lat': 59.3334682, 'lon': 18.0034399},
#    'nodes': [10799070735, 10799070734, 10799070733, 10799070732, 10799070735],
#    'tags': {'amenity': 'toilets',
#     'building': 'toilets',
#     'building:colour': 'green',
#     'changing_table': 'yes',
#     'check_date': '2024-05-26',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 1174535358,
#    'center': {'lat': 59.3396968, 'lon': 18.0374134},
#    'nodes': [10913999523, 10913999522, 10913999521, 10913999520, 10913999523],
#    'tags': {'amenity': 'toilets',
#     'building': 'toilets',
#     'building:levels': '1'}},
#   {'type': 'way',
#    'id': 1188355348,
#    'center': {'lat': 59.2898104, 'lon': 18.0381008},
#    'nodes': [11034745575, 11034745582, 11034745577, 11034745578, 11034745575],
#    'tags': {'amenity': 'toilets', 'building': 'yes', 'building:levels': '1'}},
#   {'type': 'way',
#    'id': 1256882568,
#    'center': {'lat': 59.3537006, 'lon': 18.0655017},
#    'nodes': [11684820441,
#     11684820437,
#     11684820439,
#     11684820438,
#     11684820442,
#     11684820441],
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'indoor': 'room',
#     'level': '1',
#     'level:ref': '2'}},
#   {'type': 'way',
#    'id': 1256882572,
#    'center': {'lat': 59.3537257, 'lon': 18.0652808},
#    'nodes': [11684820453,
#     11684820452,
#     11684820451,
#     11684835678,
#     11684820455,
#     11684820453],
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'indoor': 'room',
#     'level': '1',
#     'level:ref': '2',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 1256882574,
#    'center': {'lat': 59.3535385, 'lon': 18.0654244},
#    'nodes': [11684820459,
#     11684820458,
#     11684820457,
#     11684820463,
#     11684820456,
#     11684820459],
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'indoor': 'room',
#     'level': '1',
#     'level:ref': '2'}},
#   {'type': 'way',
#    'id': 1256882577,
#    'center': {'lat': 59.353367, 'lon': 18.0653879},
#    'nodes': [11684835670,
#     11684835669,
#     11684820468,
#     11684820465,
#     11684835671,
#     11684835670],
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'indoor': 'room',
#     'level': '1',
#     'level:ref': '2'}},
#   {'type': 'way',
#    'id': 1256882578,
#    'center': {'lat': 59.3533689, 'lon': 18.0653657},
#    'nodes': [11684835671,
#     11684835670,
#     11684835673,
#     11684835672,
#     11684820466,
#     11684835671],
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'indoor': 'room',
#     'level': '1',
#     'level:ref': '2'}},
#   {'type': 'way',
#    'id': 1256882579,
#    'center': {'lat': 59.3533707, 'lon': 18.0653429},
#    'nodes': [11684835675,
#     11684835674,
#     11684835673,
#     11684835672,
#     11684820467,
#     11684835675],
#    'tags': {'amenity': 'toilets',
#     'fee': 'no',
#     'indoor': 'room',
#     'level': '1',
#     'level:ref': '2'}},
#   {'type': 'way',
#    'id': 1293232556,
#    'center': {'lat': 59.3399616, 'lon': 18.0049056},
#    'nodes': [11988616037, 11988616034, 11988616035, 11988616036, 11988616037],
#    'tags': {'amenity': 'toilets', 'building': 'toilets'}},
#   {'type': 'way',
#    'id': 1299713131,
#    'center': {'lat': 59.3478759, 'lon': 18.0521754},
#    'nodes': [12039444325, 12039444324, 12039444323, 12039444322, 12039444325],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 1300101878,
#    'center': {'lat': 59.3343858, 'lon': 18.0627637},
#    'nodes': [12042453872,
#     12042453873,
#     12042454269,
#     12042454270,
#     12042454089,
#     12042453872],
#    'tags': {'amenity': 'toilets',
#     'fee': 'yes',
#     'indoor': 'room',
#     'level': '-1',
#     'room': 'toilet',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 1300101880,
#    'center': {'lat': 59.3343386, 'lon': 18.0628342},
#    'nodes': [12042453876, 12042453877, 12042454274, 12042454275, 12042453876],
#    'tags': {'amenity': 'toilets',
#     'fee': 'yes',
#     'indoor': 'room',
#     'level': '-1',
#     'room': 'toilet'}},
#   {'type': 'way',
#    'id': 1314795619,
#    'center': {'lat': 59.4119463, 'lon': 17.9129857},
#    'nodes': [12169483792, 12169483793, 12169483794, 12169483795, 12169483792],
#    'tags': {'amenity': 'toilets',
#     'building': 'yes',
#     'mapillary': '1238696544225660',
#     'portable': 'yes',
#     'seasonal': 'yes',
#     'toilets': 'unisex'}},
#   {'type': 'way',
#    'id': 1314795620,
#    'center': {'lat': 59.4119393, 'lon': 17.9129581},
#    'nodes': [12169483796, 12169483797, 12169483798, 12169483799, 12169483796],
#    'tags': {'access': 'public',
#     'amenity': 'toilets',
#     'mapillary': '443331782189894',
#     'portable': 'yes',
#     'seasonal': 'yes',
#     'toilets': 'unisex'}},
#   {'type': 'way',
#    'id': 1409423170,
#    'center': {'lat': 59.3316929, 'lon': 18.0280295},
#    'nodes': [12951349382, 12951349383, 12951349381, 12951349384, 12951349382],
#    'tags': {'amenity': 'toilets', 'building': 'toilets', 'fee': 'no'}},
#   {'type': 'way',
#    'id': 1415635429,
#    'center': {'lat': 59.4072252, 'lon': 17.9186858},
#    'nodes': [13009022015, 13009022016, 13009022017, 13009022018, 13009022015],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'charge': '5 SEK',
#     'check_date': '2026-01-24',
#     'description': 'Paid: 5 SEK with ORC kod',
#     'fee': 'yes',
#     'image': 'https://commons.wikimedia.org/wiki/File:Stockholms_stads_offentliga_toalett_Husby_g%C3%A5rd_08.jpg',
#     'image:license': 'CC0',
#     'mapillary': '886390654010210',
#     'payment:cash': 'no',
#     'payment:credit_cards': 'yes',
#     'toilets:disposal': 'flush',
#     'toilets:handwashing': 'yes',
#     'toilets:num_chambers': '2',
#     'toilets:paper_supplied': 'yes',
#     'toilets:position': 'seated',
#     'wheelchair': 'yes',
#     'wikimedia_commons': 'Category:Public_toilets_in_Stockholm'}},
#   {'type': 'way',
#    'id': 1416774606,
#    'center': {'lat': 59.3503957, 'lon': 18.0679408},
#    'nodes': [13019274026,
#     13019274027,
#     13019649944,
#     13019274028,
#     13019274030,
#     13019274029,
#     13019274026],
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'indoor': 'room',
#     'level': '0',
#     'room': 'toilet',
#     'toilets:disposal': 'flush',
#     'toilets:menstrual_products': 'yes',
#     'unisex': 'yes'}},
#   {'type': 'way',
#    'id': 1416774616,
#    'center': {'lat': 59.350584, 'lon': 18.0675281},
#    'nodes': [13019274053,
#     13019274054,
#     13019274055,
#     13019274056,
#     13019274069,
#     13019274053],
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'indoor': 'room',
#     'level': '-1',
#     'room': 'toilet',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes'}},
#   {'type': 'way',
#    'id': 1416774617,
#    'center': {'lat': 59.3505893, 'lon': 18.0674893},
#    'nodes': [13019274055,
#     13019274057,
#     13019274058,
#     13019274059,
#     13019274070,
#     13019274053,
#     13019274054,
#     13019274055],
#    'tags': {'access': 'customers',
#     'amenity': 'toilets',
#     'indoor': 'room',
#     'level': '-1',
#     'room': 'toilet',
#     'toilets:disposal': 'flush',
#     'unisex': 'yes'}},
#   {'type': 'way',
#    'id': 1427716359,
#    'center': {'lat': 59.4131655, 'lon': 17.9115085},
#    'nodes': [13125143626, 13125143627, 13125143628, 13125143629, 13125143626],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'charge': '5 Skr',
#     'check_date': '2026-01-24',
#     'fee': 'yes',
#     'image': 'https://commons.wikimedia.org/wiki/File:Stockholms_stads_offentliga_toalett_Akalla_g%C3%A5rd_01.jpg',
#     'image:license': 'CC0',
#     'mapillary': '725324120420672',
#     'payment:cash': 'no',
#     'payment:credit_cards': 'yes',
#     'toilets:disposal': 'flush',
#     'toilets:handwashing': 'yes',
#     'toilets:num_chambers': '1',
#     'toilets:paper_supplied': 'yes',
#     'toilets:position': 'seated',
#     'wheelchair': 'yes',
#     'wikimedia_commons': 'Category:Public_toilets_in_Stockholm'}},
#   {'type': 'way',
#    'id': 1463157733,
#    'center': {'lat': 59.3478225, 'lon': 18.0369866},
#    'nodes': [13421310284, 13421310283, 13421310282, 13421310281, 13421310284],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'changing_table': 'yes',
#     'check_date': '2024-09-06',
#     'fee': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'way',
#    'id': 1469874749,
#    'center': {'lat': 59.3955268, 'lon': 17.9048981},
#    'nodes': [13479780299, 13479780300, 13480002601, 13480002602, 13479780299],
#    'tags': {'access': 'no',
#     'addr:street': 'Jyllandsgatan 16',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'check_date': '2026-01-22',
#     'disused:amenity': 'toilets',
#     'mapillary': '1285038303658452',
#     'note': 'Closed due to Stockholm City supplier change; planned new toilets later in year',
#     'operator': 'Stockholms stad',
#     'source:access': 'https://trafik.stockholm/gator-torg/offentliga-toaletter/'}},
#   {'type': 'way',
#    'id': 1470142807,
#    'center': {'lat': 59.4017563, 'lon': 17.9425},
#    'nodes': [13482782517, 13482782518, 13482782519, 13482782520, 13482782517],
#    'tags': {'access': 'yes',
#     'amenity': 'toilets',
#     'charge': '5 Skr',
#     'check_date': '2026-01-24',
#     'description': 'Paid: 5 SEK',
#     'fee': 'yes',
#     'image': 'https://commons.wikimedia.org/wiki/File:Stockholms_stads_offentliga_toalett_Kista_torg_01.jpg',
#     'mapillary': '886390654010210',
#     'payment:cash': 'no',
#     'payment:credit_cards': 'yes',
#     'toilets:disposal': 'flush',
#     'toilets:handwashing': 'yes',
#     'toilets:num_chambers': '2',
#     'toilets:paper_supplied': 'yes',
#     'toilets:position': 'seated',
#     'unisex': 'yes',
#     'wheelchair': 'yes',
#     'wikimedia_commons': 'Category:Public_toilets_in_Stockholm'}},
#   {'type': 'way',
#    'id': 1470202519,
#    'center': {'lat': 59.4000603, 'lon': 17.9356265},
#    'nodes': [13483397023, 13483397024, 13483397026, 13483397025, 13483397023],
#    'tags': {'access': 'no',
#     'addr:street': 'Jyllandsgatan 16',
#     'amenity': 'toilets',
#     'building': 'yes',
#     'check_date': '2026-01-22',
#     'disused:amenity': 'toilets',
#     'image': 'https://commons.wikimedia.org/wiki/File:Stockholms_stads_offentliga_toalett_Jyllandsgatan_16_Kista_06.jpg',
#     'image:license': 'CC0',
#     'note': 'Closed due to Stockholm City supplier change; planned new toilets later in year',
#     'operator': 'Stockholms stad',
#     'source:access': 'https://trafik.stockholm/gator-torg/offentliga-toaletter/'}}]}

# %%
with open("osm_data.json", "w", encoding="utf-8") as f:
    json.dump(osm_data, f, indent=2, ensure_ascii=False)

# %% [markdown]
# # Generate Map

# %%
import folium 
m = folium.Map(location=[59.3293, 18.0686], zoom_start=11)

gdf.to_csv("Sthlm.csv")

# %%
from shapely.geometry import base

# Ta bort alla geometrier utom den huvudsakliga
gdf_clean = gdf.copy()

# ta bort "geometry_centroid" och andra geometrikolumner
geom_cols = [c for c in gdf_clean.columns 
             if c != "geometry" and gdf_clean[c].apply(lambda x: isinstance(x, base.BaseGeometry)).any()]
if geom_cols:
    print("🧹 Tar bort extra geometri-kolumner:", geom_cols)
    gdf_clean = gdf_clean.drop(columns=geom_cols, errors="ignore")

# Skapa Folium-lager utan att försöka serialisera själva geometry-kolumnen
stad_layer = folium.FeatureGroup(name="🟠 Toaletter (Stockholms stad)")

for _, row in gdf_clean.iterrows():
    if pd.isna(row["lat"]) or pd.isna(row["lon"]):
        continue

    folium.CircleMarker(
        location=[row["lat"], row["lon"]],
        radius=8,
        fill=True,
        fill_color="#ff6600",
        color="#cc5500",
        weight=2,
        fill_opacity=0.7,
        popup=folium.Popup(build_toilet_popup(row), max_width=350),
    ).add_to(stad_layer)


stad_layer.add_to(m)
# Out:
# 🧹 Tar bort extra geometri-kolumner: ['geometry_centroid']

# %%
from datetime import datetime, timezone

generated_at = datetime.now(timezone.utc).strftime("%Y-%m-%d %H:%M UTC")

# %% [markdown]
# ### Add OSM to map layer OSM
#
# 2026-01-23: 'node': 181, 'way': 56}

# %%
# should be 237 
rendered = []

for el in osm_data["elements"]:
    lat, lon = get_lat_lon(el)
    if lat is None:
        continue
    rendered.append(el)

len(rendered)
# Out:
# 239

# %%
assert len(rendered) == 239, f"Expected 239 toilets, rendered {len(rendered)}"

# %%
from datetime import date, datetime

STALE_YEARS = 3

def parse_osm_date(value):
    try:
        return datetime.strptime(value, "%Y-%m-%d").date()
    except Exception:
        return None


def classify_toilet(tags: dict) -> str:
    """
    Returns one of: fixme, stale, unknown, ok
    """
    if "fixme" in tags:
        return "fixme"

    cd = tags.get("check_date")
    if not cd:
        return "unknown"

    parsed = parse_osm_date(cd)
    if not parsed:
        return "unknown"

    age_years = date.today().year - parsed.year
    if age_years >= STALE_YEARS:
        return "stale"

    return "ok"

# %%
from folium.plugins import MarkerCluster
import folium
layers = {
    "ok": {
        "group": folium.FeatureGroup(name="✅ Toilets – recently checked"),
        "cluster": MarkerCluster(name="OK"),
        "color": "green",
    },
    "stale": {
        "group": folium.FeatureGroup(name="⚠️ Toilets – stale data"),
        "cluster": MarkerCluster(name="Stale"),
        "color": "orange",
    },
    "unknown": {
        "group": folium.FeatureGroup(name="❓ Toilets – no check_date"),
        "cluster": MarkerCluster(name="Unknown"),
        "color": "gray",
    },
    "fixme": {
        "group": folium.FeatureGroup(name="🛠 Toilets – fixme"),
        "cluster": MarkerCluster(name="Fixme"),
        "color": "red",
    },
}

for cfg in layers.values():
    cfg["cluster"].add_to(cfg["group"])

# %%
import folium

toilet_osm_layer = folium.FeatureGroup(name="🚻 OSM Toilets")

elements = osm_data.get("elements", [])


for el in osm_data["elements"]:
    lat, lon = get_lat_lon(el)
    if lat is None or lon is None:
        continue

    tags = el.get("tags", {})
    category = classify_toilet(tags)
    cfg = layers[category]

    lat, lon = get_lat_lon(el)
    if lat is None or lon is None:
        continue
    
    popup_html = build_osm_toilet_popup(el, lat=lat, lon=lon)

    folium.Marker(
        location=[lat, lon],
        popup=folium.Popup(popup_html, max_width=380),
        icon=folium.Icon(
            icon="restroom",
            prefix="fa",
            color=cfg["color"],
        ),
    ).add_to(cfg["cluster"])


for cfg in layers.values():
    cfg["group"].add_to(m)

# %% [markdown]
# ### Add legend and Sthlm

# %%
legend_html = f"""
<div style="
    position: fixed;
    bottom: 30px;
    left: 30px;
    width: 320px;
    z-index: 10000;
    font-size: 12px;
">

  <!-- Header / Toggle -->
  <div onclick="var c=document.getElementById('legend-content');
                c.style.display = (c.style.display === 'none') ? 'block' : 'none';"
       style="
        cursor: pointer;
        background: white;
        padding: 8px;
        border: 2px solid #ccc;
        border-radius: 6px 6px 0 0;
        font-weight: bold;
       ">
    🟠 Offentliga toaletter – Stockholms stad v{Mapversion}
    <span style="float:right;">▼</span>
  </div>

  <!-- Collapsible content -->
  <div id="legend-content" style="
        display: none;
        background: white;
        padding: 10px;
        border: 2px solid #ccc;
        border-top: none;
        border-radius: 0 0 6px 6px;
  ">

    <small><i>Karta genererad: {generated_at}</i></small><br><br>

    <b>Syfte</b><br>
    Datat används för att verifiera och förbättra OSM.  
    Stockholms stad gör om en hel del – se issue
    (<i>amenity=toilets</i>).<br><br>

    <b>Mer info</b><br>
    • <a href="https://github.com/salgo60/Offentliga-toaletter/issues/1" target="_blank">
      GitHub Issue #1
    </a><br>
    • <a href="https://dataportalen.stockholm.se/dataportalen/GetMetaDataById?id=LvFeature15303196&showmetadataview" target="_blank">
      Stockholms stads öppna data
    </a>

  </div>
</div>
"""

# %%
#legend_html

# %%
m.get_root().html.add_child(folium.Element(legend_html))
folium.LayerControl(collapsed=False).add_to(m)

# %%
from branca.element import MacroElement
from jinja2 import Template

class MinPlatsControl(MacroElement):
    _template = Template("""
        {% macro script(this, kwargs) %}
        var minPlats = L.control({position: 'bottomright'});

        minPlats.onAdd = function (map) {
            var div = L.DomUtil.create('div', 'min-plats-control');
            div.innerHTML = '📍 <strong>Min plats</strong>';

            // Gör klickbar
            L.DomEvent.disableClickPropagation(div);
            L.DomEvent.on(div, 'click', function (e) {
                map.locate({setView: true, maxZoom: 16});
            });

            return div;
        };

        minPlats.addTo({{this._parent.get_name()}});
        {% endmacro %}
    """)

m.add_child(MinPlatsControl())
from folium import Element

css = """
<style>
.min-plats-control {
    cursor: pointer;
    background: #cfe8ef;
    padding: 8px 12px;
    border-radius: 6px;
    box-shadow: 0 0 6px rgba(0,0,0,0.3);
    font-size: 16px;
    user-select: none;
}
.min-plats-control:hover {
    background: #b9dde7;
}
</style>
"""
m.get_root().html.add_child(Element(css))

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cab71b74bfcb2254cd0ca8dcac4d07d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 30px;
#     left: 30px;
#     width: 320px;
#     z-index: 10000;
#     font-size: 12px;
# &quot;&gt;
#
#   &lt;!-- Header / Toggle --&gt;
#   &lt;div onclick=&quot;var c=document.getElementById(&#x27;legend-content&#x27;);
#                 c.style.display = (c.style.display === &#x27;none&#x27;) ? &#x27;block&#x27; : &#x27;none&#x27;;&quot;
#        style=&quot;
#         cursor: pointer;
#         background: white;
#         padding: 8px;
#         border: 2px solid #ccc;
#         border-radius: 6px 6px 0 0;
#         font-weight: bold;
#        &quot;&gt;
#     🟠 Offentliga toaletter – Stockholms stad v0.4
#     &lt;span style=&quot;float:right;&quot;&gt;▼&lt;/span&gt;
#   &lt;/div&gt;
#
#   &lt;!-- Collapsible content --&gt;
#   &lt;div id=&quot;legend-content&quot; style=&quot;
#         display: none;
#         background: white;
#         padding: 10px;
#         border: 2px solid #ccc;
#         border-top: none;
#         border-radius: 0 0 6px 6px;
#   &quot;&gt;
#
#     &lt;small&gt;&lt;i&gt;Karta genererad: 2026-01-25 14:11 UTC&lt;/i&gt;&lt;/small&gt;&lt;br&gt;&lt;br&gt;
#
#     &lt;b&gt;Syfte&lt;/b&gt;&lt;br&gt;
#     Datat används för att verifiera och förbättra OSM.
#     Stockholms stad gör om en hel del – se issue
#     (&lt;i&gt;amenity=toilets&lt;/i&gt;).&lt;br&gt;&lt;br&gt;
#
#     &lt;b&gt;Mer info&lt;/b&gt;&lt;br&gt;
#     • &lt;a href=&quot;https://github.com/salgo60/Offentliga-toaletter/issues/1&quot; target=&quot;_blank&quot;&gt;
#       GitHub Issue #1
#     &lt;/a&gt;&lt;br&gt;
#     • &lt;a href=&quot;https://dataportalen.stockholm.se/dataportalen/GetMetaDataById?id=LvFeature15303196&amp;showmetadataview&quot; target=&quot;_blank&quot;&gt;
#       Stockholms stads öppna data
#     &lt;/a&gt;
#
#   &lt;/div&gt;
# &lt;/div&gt;
#
# &lt;style&gt;
# .min-plats-control {
#     cursor: pointer;
#     background: #cfe8ef;
#     padding: 8px 12px;
#     border-radius: 6px;
#     box-shadow: 0 0 6px rgba(0,0,0,0.3);
#     font-size: 16px;
#     user-select: none;
# }
# .min-plats-control:hover {
#     background: #b9dde7;
# }
# &lt;/style&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cab71b74bfcb2254cd0ca8dcac4d07d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cab71b74bfcb2254cd0ca8dcac4d07d = L.map(
#                 &quot;map_2cab71b74bfcb2254cd0ca8dcac4d07d&quot;,
#                 {
#                     center: [59.3293, 18.0686],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75592d2e7c877c74a6e56f9c0828694a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75592d2e7c877c74a6e56f9c0828694a.addTo(map_2cab71b74bfcb2254cd0ca8dcac4d07d);
#
#
#             var feature_group_b0b444efe7b2b318ae5a1e4e689b4022 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_a128ecca349d261cd992d8b693d8c86c = L.circleMarker(
#                 [59.32999303270969, 18.00287085334272],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#cc5500&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff6600&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(feature_group_b0b444efe7b2b318ae5a1e4e689b4022);
#
#
#         var popup_c7f4c7af8a1fab533582294f3952f0aa = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_afe68c5d11b682e7a44b19023f995739 = $(`&lt;div id=&quot;html_afe68c5d11b682e7a44b19023f995739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&#x27;font-family:Arial; font-size:13px; max-width:320px;&#x27;&gt;       &lt;b&gt;🚻 Offentlig toalett&lt;/b&gt;&lt;br&gt;       &lt;b&gt;Adress:&lt;/b&gt; Frödingsvägen 13&lt;br&gt;       &lt;b&gt;Status:&lt;/b&gt; I funktion&lt;br&gt;       &lt;b&gt;D

# %%
# Exportera kartan https://salgo60.github.io/Offentliga-toaletter/Notebook/Toaletter_sthlm.html
html_map_file = "Toaletter_sthml_" + Mapversion.replace(".", "_") + ".html"
m.save(html_map_file) 
m.save("Toaletter_sthlm_latest.html")

# %%
html_map_file
# Out:
# 'Toaletter_sthml_0_4.html'

# %%
 # End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time# Bygg audit-lager för den här etappen

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print("Total time elapsed: {:.2f} seconds".format(elapsed_time))
# Out:
# Date: 2026-01-25 15:11:28
# Total time elapsed: 292.97 seconds
